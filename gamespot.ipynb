# %%
import os
from dotenv import load_dotenv
from requests import get
import requests 
import json
import pandas as pd

# %%
load_dotenv()
url = 'http://www.gamespot.com/api/games/?'
API_KEY = os.getenv('GAMESPOT_API_KEY')

# %% [markdown]
# headers = {
#     'User-Agent' : 'project1',
# }

# %%
params = {
    'api_key': API_KEY,
    'format': 'json'
}

headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36',
    'content-type': 'application/json; charset=utf-8',
    'Accept': '*/*',
    'Connection': 'keep-alive'
}

# %%
res = get(url=url, params=params,headers=headers)
print(res)
# Out:
# <Response [200]>

# %%
res.json().get('results')
# Out:
# [{'release_date': '1995-09-26 12:00:00',
#   'description': "Welcome to the New World Order. A gritty high tech world where the art of electronic intelligence and covert surveillance reigns supreme. Where guerrilla strategies and savage combat are the norm. Build bases, muster forces and lacerate your enemies to the bone. All for the love of power. In the hyper-real combat experience of Command & Conquer, you're thrust into the heat of an all out race for global control. Will you side with the humanistic GDI or bring the world to its knees with the Brotherhood of Nod? Decide fast. Your adversaries are without mercy. And so are you.",
#   'id': 1,
#   'name': 'Command & Conquer',
#   'deck': 'Overall Command & Conquer is a great strategy game and easily the best available on the PlayStation.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/0/9/6/2/2210962-cncbox.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/0/9/6/2/2210962-cncbox.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/0/9/6/2/2210962-cncbox.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/0/9/6/2/2210962-cncbox.jpg'},
#   'genres': [{'name': 'Real-Time'}, {'name': 'Strategy'}],
#   'themes': [{'name': 'Sci-Fi'}],
#   'franchises': [{'name': 'Command & Conquer'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-1',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-1',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-1',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-1',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-1',
#   'site_detail_url': 'https://www.gamespot.com/command-and-conquer/'},
#  {'release_date': '1996-03-31 12:00:00',
#   'description': "Relive those carefree and exciting days when every quarter burned a hole in your pocket. Return of Microsoft Arcade puts you in command of four hot arcade classics - replicated exactly for the PC!\nReturn of Microsoft Arcade - for pulse-pounding action and fun!\n\nPac-Man\nBe quick, be fearless: chomp away on the does and avoid those four relentless ghosts, level after level! One of the all-time favorite arcade games, Pac-Man will whisk you back to those good old days and get you addicted all over again, right on your PC!\n\nPole Position \nLadies and gentlemen, start your engines! Pole Position is a thrill a minute behind the wheel, as you challenge hot competitors on a tortuous, twisting track. It's non-stop fun - a total crack-up you'd never want to try in your own car!\n\nDig-Dug\nUse your skill and daring to burrow your way to survival and victory in this popular and challenging game! As the heroic Dig-Dug, you have to battle Fygar the fire-breathing Dragon and escape the relentless pursuit of Pooka. You're going to dig it!\n\nGalaxian \nHead for deep space and get the bugs out of it! To destroy the alien flagship and its endless stream of escort vessels, you must elude the missiles fired at you by the insect-like spacecraft. The better you do, the more threatening the swarms of invaders become. It's a classic space-war game!",
#   'id': 2,
#   'name': 'Return of Arcade',
#   'deck': 'For nostalgia buffs, these old games are worth your time and money, though you will miss the feel of the arcade controller.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/box/1/8/2-18.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/box/1/8/2-18.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/box/1/8/2-18.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/box/1/8/2-18.jpg'},
#   'genres': [{'name': 'Compilation'}],
#   'themes': [],
#   'franchises': [{'name': 'Microsoft Arcade'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-2',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-2',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-2',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-2',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-2',
#   'site_detail_url': 'https://www.gamespot.com/return-of-arcade/'},
#  {'release_date': '1995-11-30 12:00:00',
#   'description': 'From the combined talents of LucasArts and legendary filmmaker Steven Spielberg comes an epic adventure that plunges headlong into the very core of the unknown.  And takes you with it.',
#   'id': 3,
#   'name': 'The Dig',
#   'deck': "In almost every sense, The Dig represents a leap backwards from LucasArts' previous group of adventure games.",
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/0/0/4/6/2210046-the_dig_box_front_6570x8280.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/0/0/4/6/2210046-the_dig_box_front_6570x8280.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/0/0/4/6/2210046-the_dig_box_front_6570x8280.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/0/0/4/6/2210046-the_dig_box_front_6570x8280.jpg'},
#   'genres': [{'name': 'Adventure'}],
#   'themes': [],
#   'franchises': [],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-3',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-3',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-3',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-3',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-3',
#   'site_detail_url': 'https://www.gamespot.com/the-dig/'},
#  {'release_date': '1995-11-30 12:00:00',
#   'description': '',
#   'id': 4,
#   'name': 'Mission Critical',
#   'deck': 'Put simply, Mission Critical was one of the best adventures of 1995.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/5/7/0/5/2215705-g00770r2t3r.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/5/7/0/5/2215705-g00770r2t3r.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/5/7/0/5/2215705-g00770r2t3r.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/5/7/0/5/2215705-g00770r2t3r.jpg'},
#   'genres': [{'name': 'Adventure'}],
#   'themes': [],
#   'franchises': [],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-4',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-4',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-4',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-4',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-4',
#   'site_detail_url': 'https://www.gamespot.com/mission-critical/'},
#  {'release_date': '1996-06-30 12:00:00',
#   'description': '',
#   'id': 5,
#   'name': 'Links LS: Legends in Sports 1997 Edition',
#   'deck': 'With this update, Links LS can rightfully reclaim its status as the king of golf sims.',
#   'image': {'original': 'https://www.gamespot.com/a/uploads/original/box/2/8/5-28.jpg'},
#   'genres': [{'name': 'Golf'}, {'name': 'Simulation'}, {'name': 'Sports'}],
#   'themes': [],
#   'franchises': [{'name': 'Links Golf'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-5',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-5',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-5',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-5',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-5',
#   'site_detail_url': 'https://www.gamespot.com/links-ls-legends-in-sports-1997-edition/'},
#  {'release_date': '1995-11-30 12:00:00',
#   'description': 'A LONG TIME AGO IN A GALAXY FAR, FAR AWAY... This completely original chapter in the Star Wars saga offers breakthrough technology in graphics and an entirely new storyline. Experience the most exhilarating and interactive space combat in this or any galaxy.',
#   'id': 6,
#   'name': 'Star Wars Rebel Assault II: The Hidden Empire',
#   'deck': 'Rebel Assault II  will be enough to satisfy those seeking a worthwhile multimedia "experience," but the limited gameplay will send hard-core gamers running back to Tie Fighter.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/box/2/9/6-29.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/box/2/9/6-29.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/box/2/9/6-29.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/box/2/9/6-29.jpg'},
#   'genres': [{'name': '3D'},
#    {'name': 'Action'},
#    {'name': 'On-Rails'},
#    {'name': 'Shooter'}],
#   'themes': [],
#   'franchises': [{'name': 'Star Wars'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-6',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-6',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-6',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-6',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-6',
#   'site_detail_url': 'https://www.gamespot.com/star-wars-rebel-assault-ii-the-hidden-empire/'},
#  {'release_date': '1995-11-30 12:00:00',
#   'description': "Brona's evil spirit has come back to wreak revenge upon those who killed him. Now, only the combined magic of the races can destroy him.\r\nYou are Jak Ohmsford. Only you can overcome the ancestral hatreds that divide the Four Lands, and only you can wield the magic that will defeat Brona. It is your destiny to save your homeland - but the price of destiny is far higher than you could have ever imagined.",
#   'id': 7,
#   'name': 'Shannara',
#   'deck': 'Shannara is an excellent pick for novice users or fans of Mr. Brooks, but experienced players should probably keep looking.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/6/7/6/3/2216763-shannara.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/6/7/6/3/2216763-shannara.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/6/7/6/3/2216763-shannara.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/6/7/6/3/2216763-shannara.jpg'},
#   'genres': [{'name': 'Adventure'}],
#   'themes': [],
#   'franchises': [],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-7',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-7',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-7',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-7',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-7',
#   'site_detail_url': 'https://www.gamespot.com/shannara/'},
#  {'release_date': '1995-10-31 12:00:00',
#   'description': "Lights blur. The crowd whizzes past. Your helmet rattles against the roll bar and the competition switches into overdrive. Tears stream from your face as the race moves into extreme speed. Tears of sweat. The same stuff that's seeping out of your palms and onto the steering wheel. Get a grip. You're sliding into a turn at 200 miles per hour and centrifugal force will only carry you so far.\n\nThis is velocity-driven, pedal-to-the-metal arcade auto racing. It ain't no simulation. Find out how your PC really handles 'cause you've never been allowed to go this fast before. Maneuver through a twisted landscape, along six snakin' tracks with other racers breathing down your neck, and post a time that's warped. Strapped into a personally chosen, made-for-the-autobahn racing machine, you'll scream to redefine fast in this winding 3-D ride of pure rocketing fun.\n\n*Exhilirating gameplay featuring sonic speed arcade racing action\n*6 punishing tracks and 12 precision automobiles (6 automatic & 6 manual)\n*Zooming graphics tearing through a real-time 3-D texture-mapped environment\n*Switchable points-of-view including behind the wheel and chase mode\n*Multi-player options challenge up to 7 players via network play\n*Jam to the action with heart-pumping thrash metal and realistic sound effects\n*Supports major peripherals (Thrustmaster T1, T2, Virtual Pilot, any digital or analog joysticks)",
#   'id': 8,
#   'name': 'Screamer',
#   'deck': 'Screamer shuns the pit stops, personnel moves, and car equipment upgrades that have become familiar to racing fans in favor of colorful, straightforward, hard-driving action.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/5/7/4/4/2215744-screamer1_box.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/5/7/4/4/2215744-screamer1_box.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/5/7/4/4/2215744-screamer1_box.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/5/7/4/4/2215744-screamer1_box.jpg'},
#   'genres': [{'name': 'Arcade'}, {'name': 'Driving/Racing'}],
#   'themes': [],
#   'franchises': [{'name': 'Screamer'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-8',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-8',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-8',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-8',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-8',
#   'site_detail_url': 'https://www.gamespot.com/screamer/'},
#  {'release_date': '1995-07-31 12:00:00',
#   'description': 'ENTER THE COMIX ZONE: THE FIRST TRULY INTERACTIVE COMIC BOOK! Play as Sketch Turner, a street-wise comic book artist who gets trapped in the comic book world of his own creation. Warp into the Comix Zone with all the action and adventure of your favorite comics! Battle panel by panel through full comic book pages drawn by real comic book artists! Sharpen your fighting skills to defeat mutant enemies drawn in by Mortus, public enemy no. 1. Rip up the page with superhero power-ups and tons of intense fighting moves!',
#   'id': 9,
#   'name': 'Comix Zone',
#   'deck': '',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/9/4/0/7/2209407-genesis_comixzone.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/9/4/0/7/2209407-genesis_comixzone.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/9/4/0/7/2209407-genesis_comixzone.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/9/4/0/7/2209407-genesis_comixzone.jpg'},
#   'genres': [{'name': '2D'}, {'name': 'Action'}, {'name': "Beat-'Em-Up"}],
#   'themes': [],
#   'franchises': [],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-9',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-9',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-9',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-9',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-9',
#   'site_detail_url': 'https://www.gamespot.com/comix-zone/'},
#  {'release_date': '1996-06-22 12:00:00',
#   'description': 'From the creators of DOOM and DOOM II comes the most intense, technologically advanced 3-D experience ever captured on CD ROM. Features free and fluid motion, ambient sound and lighting, and unmatched multi-player capabilities. (Play with up to 15 others via internet, modem, LAN, or serial connection.)',
#   'id': 10,
#   'name': 'Quake',
#   'deck': "If you're into action games, or even if you're not, you should be playing Quake right now - it's as good as PC gaming gets.",
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/2/8/6/2/2212862-dfvgbhnm.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/2/8/6/2/2212862-dfvgbhnm.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/2/8/6/2/2212862-dfvgbhnm.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/2/8/6/2/2212862-dfvgbhnm.jpg'},
#   'genres': [{'name': '3D'},
#    {'name': 'Action'},
#    {'name': 'First-Person'},
#    {'name': 'Shooter'}],
#   'themes': [{'name': 'Sci-Fi'}],
#   'franchises': [{'name': 'Quake'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-10',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-10',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-10',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-10',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-10',
#   'site_detail_url': 'https://www.gamespot.com/quake/'},
#  {'release_date': '1997-11-30 12:00:00',
#   'description': '',
#   'id': 11,
#   'name': 'Red Baron II',
#   'deck': "Red Baron II has a lot to offer, but its rushed shipment makes for a game that's appealing only to those sim fans willing to deal with quirks and inconsistencies while awaiting patches.",
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/3/2/7/7/2213277-red_baron_2_a.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/3/2/7/7/2213277-red_baron_2_a.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/3/2/7/7/2213277-red_baron_2_a.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/3/2/7/7/2213277-red_baron_2_a.jpg'},
#   'genres': [{'name': 'Flight'}, {'name': 'Simulation'}],
#   'themes': [{'name': 'Historic'}, {'name': 'Military'}],
#   'franchises': [{'name': 'Red Baron'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-11',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-11',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-11',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-11',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-11',
#   'site_detail_url': 'https://www.gamespot.com/red-baron-ii/'},
#  {'release_date': '1994-06-09 12:00:00',
#   'description': "Jim wasn't always a studly super-worm. He was once just a spineless, dirt eater with no real mission in life... Then a cosmic twist of fate placed him in control of an ultra-high-tech-indestructible-super-space-cyber-suit. Now Jim must make it to Princess-What's-Her-Name by staying clear of Psy-Crow, the intergalactic bounty hunter, until the final battle with Queen Slug-for-a-Butt.",
#   'id': 12,
#   'name': 'Earthworm Jim',
#   'deck': "It's a video game, it's a cartoon, it's a toy, it's a lunch box, and now it's a PC CD-ROM game.",
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/4/4/4/4/2214444-genesis_earthwormjim.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/4/4/4/4/2214444-genesis_earthwormjim.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/4/4/4/4/2214444-genesis_earthwormjim.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/4/4/4/4/2214444-genesis_earthwormjim.jpg'},
#   'genres': [{'name': '2D'}, {'name': 'Action'}, {'name': 'Platformer'}],
#   'themes': [],
#   'franchises': [{'name': 'Earthworm Jim'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-12',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-12',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-12',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-12',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-12',
#   'site_detail_url': 'https://www.gamespot.com/earthworm-jim/'},
#  {'release_date': '1996-01-01 12:00:00',
#   'description': "Defeat the enemy in nonstop World War II battle action. Lead your men through the terror, fatigue, and hell of war on to victory. Only you can bring 'em back alive!\n\nIt's 4 A.M. Your men are dog-tired. They're desperately trying to take the bridge. They're under heavy fire. Casualties are mounting. You order your armor to move up. Two platoons of infantry to follow. But some of your men won't budge. Some are even retreating. You've got to take that bridge and time's running out. What do you do?",
#   'id': 13,
#   'name': 'Close Combat',
#   'deck': 'A typical day at the beach: the sand under your feet, the roar of the surf... and the ripping sound of German machine guns as they cut your troops to pieces.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/2/5/7/9/2212579-battle.png',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/2/5/7/9/2212579-battle.png',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/2/5/7/9/2212579-battle.png',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/2/5/7/9/2212579-battle.png'},
#   'genres': [{'name': 'Real-Time'}, {'name': 'Strategy'}],
#   'themes': [{'name': 'Historic'}],
#   'franchises': [{'name': 'Close Combat'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-13',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-13',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-13',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-13',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-13',
#   'site_detail_url': 'https://www.gamespot.com/close-combat/'},
#  {'release_date': '1997-03-31 12:00:00',
#   'description': "The Most Dangerous Man is the One with Nothing Left to Lose.\nWhen outlaws murdered your wife, and took your daughter, everything you had was gone. Your gut aches for blood and sweet revenge. Dyin's too good for 'em now.\nRide back into the wild west as the gun-slinging Marshall James Anderson. You'll encounter a dusty town, an abandoned mine, a runaway train, and the orneriest cowpokes this side of the Mississippi as you uncover a twisted plot of greed and corruption.\nWith weapons like your six-shooting .45, your .44 rifle, your 10-gauge shotgun and your good ol' sawed off 12-gauge, you'll be packin' plenty of fire power.\nNothing warms the heart of a cold-blooded killer like hot lead.\nIt's Payback Time.\n- Three Game Variations--Spaghetti Western Shooter, Bounty Hunter Action & Multiplayer Shootouts.\n- Challenges the wit as well the trigger finger--Shooting the civilians may leave you swinging from a rope.\n- Multiplayer games--Supports 2 to 8 players over modem, network or Internet. Form your own gang and hit the trail.",
#   'id': 14,
#   'name': 'Outlaws',
#   'deck': "From the opening level, you'll know you're in for a movie-worthy experience.",
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/9/5/3/6/2209536-250px_outlawslucasartsboxcover.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/9/5/3/6/2209536-250px_outlawslucasartsboxcover.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/9/5/3/6/2209536-250px_outlawslucasartsboxcover.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/9/5/3/6/2209536-250px_outlawslucasartsboxcover.jpg'},
#   'genres': [{'name': '3D'},
#    {'name': 'Action'},
#    {'name': 'First-Person'},
#    {'name': 'Shooter'}],
#   'themes': [{'name': 'Historic'}],
#   'franchises': [],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-14',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-14',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-14',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-14',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-14',
#   'site_detail_url': 'https://www.gamespot.com/outlaws/'},
#  {'release_date': '1996-11-30 12:00:00',
#   'description': "Diablo invites you to enter a world of dark gothic fantasy. Play as a brave warrior, cunning rogue, or mysterious sorcerer. As you venture deeper into the labyrinth, you'll discover weapons, armor, and magical treasures; you will also develop your character's skills and abilities. You might want to bring a friend or two to help--built-in support for Battle.net, as well as modem, serial, and network play, ensures that you'll never have to go in alone.",
#   'id': 15,
#   'name': 'Diablo',
#   'deck': 'Diablo is the best game to come out in the past year, and you should own a copy. Period.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/1/8/0/1/2211801-diablo.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/1/8/0/1/2211801-diablo.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/1/8/0/1/2211801-diablo.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/1/8/0/1/2211801-diablo.jpg'},
#   'genres': [{'name': 'Action'}, {'name': 'Role-Playing'}],
#   'themes': [],
#   'franchises': [{'name': 'Diablo'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-15',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-15',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-15',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-15',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-15',
#   'site_detail_url': 'https://www.gamespot.com/diablo/'},
#  {'release_date': '1995-02-28 12:00:00',
#   'description': "Behind a veil of secrecy the evil Empire is creating a doomsday army - one that, if finished, will become the final cog in the Empire's arsenal of terror and domination.\r\n\r\nYour Mission?\r\n\r\nJoin the Rebel Alliance's covert operations division, infiltrate the Empire, then battle every man and machine the Imperial Forces can muster. Search a vast galaxy for clues, attack enemy bases - all in a desperate attempt to stop the activation of this fearsome new weapon.\r\n\r\nIt's you and your blaster against an entire Empire.\r\n\r\nMay the Force be with you.",
#   'id': 16,
#   'name': 'Star Wars: Dark Forces',
#   'deck': 'To its credit, Dark Forces is a good game that doesn\'t "play itself" like the Rebel Assault games do.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/box/1/1/0/16-110.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/box/1/1/0/16-110.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/box/1/1/0/16-110.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/box/1/1/0/16-110.jpg'},
#   'genres': [{'name': '3D'},
#    {'name': 'Action'},
#    {'name': 'First-Person'},
#    {'name': 'Shooter'}],
#   'themes': [{'name': 'Sci-Fi'}],
#   'franchises': [{'name': 'Star Wars: Dark Forces / Jedi Knight'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-16',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-16',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-16',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-16',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-16',
#   'site_detail_url': 'https://www.gamespot.com/star-wars-dark-forces/'},
#  {'release_date': '1996-12-31 12:00:00',
#   'description': "The World's Best-Loved Word Game...\n\n... is now the ultimate interactive word game! Enhanced features like 3-D board graphics, Mini-Games, multiple skill levels and pop-up screen menus give you more ways to have fun while getting your highest score ever!\n\nIt's everything you love about the Scrabble game - plus a whole lot more!",
#   'id': 17,
#   'name': 'Scrabble (1996)',
#   'deck': 'Scrabble was made for computer play.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/box/1/2/2/17-122.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/box/1/2/2/17-122.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/box/1/2/2/17-122.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/box/1/2/2/17-122.jpg'},
#   'genres': [{'name': 'Trivia/Board Game'}],
#   'themes': [],
#   'franchises': [{'name': 'Scrabble'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-17',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-17',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-17',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-17',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-17',
#   'site_detail_url': 'https://www.gamespot.com/scrabble-1996/'},
#  {'release_date': '1996-10-17 12:00:00',
#   'description': "So, you think you're a jock? Well, it don't mean JACK now.\n\nYOU DON'T KNOW JACK Sports is a hilarious and irreverent All-New, All-Sports trivia game. With all the style and humor of the original award-winning YOU DON'T KNOW JACK, JACK Sports will have sports enthusiasts and apathetics alike laughing for hours.\n\nThink you know everything about football, basketball, baseball or hockey? How about tennis, volleyball, golf or lawn darts? Even if you don't know who had the most RBIs in the Majors in 1959, or who won the Super Bowl in 1975, you can still light up the scoreboard.\n\nYOU DON'T KNOW JACK Sports - the quiz show where high culture, pop culture and sports collide.\n\nA stand-alone product with 800 All-Sports questions.\nHilarious, classic combinations of sports and pop-culture.\nAll-New sporty graphics.\nThe fastest game play in its league.\n1, 2 or 3 players duke it out on one keyboard - NO additional equipment required.\nTournament play is perfect for parties and social events.",
#   'id': 18,
#   'name': "You Don't Know Jack: Sports",
#   'deck': "I'm pleased to report that they've truly hit the long ball once again.",
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/9/6/9/0/2209690-sports.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/9/6/9/0/2209690-sports.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/9/6/9/0/2209690-sports.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/9/6/9/0/2209690-sports.jpg'},
#   'genres': [{'name': 'Trivia/Board Game'}],
#   'themes': [{'name': 'Game Show'}],
#   'franchises': [{'name': "You Don't Know Jack"}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-18',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-18',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-18',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-18',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-18',
#   'site_detail_url': 'https://www.gamespot.com/you-dont-know-jack-sports/'},
#  {'release_date': '1996-12-31 12:00:00',
#   'description': 'Now you can play anyone, anytime, anywhere with Risk, the game of global domination. Using the same hands-on military planning found in the original Risk board game, players now see battles come to life. With each battle comes the chance for victory and advice from historic military leaders as you earn medals and special bonus content for strategic accomplishments. This product will deliver a truly unique way to play the Risk game and provide an ideal social experience for up to six players in multiplayer mode and online.',
#   'id': 19,
#   'name': 'Risk',
#   'deck': 'The best computerized version of Risk yet.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/box/1/2/5/19-125.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/box/1/2/5/19-125.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/box/1/2/5/19-125.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/box/1/2/5/19-125.jpg'},
#   'genres': [{'name': 'Trivia/Board Game'}],
#   'themes': [],
#   'franchises': [{'name': 'Risk'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-19',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-19',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-19',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-19',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-19',
#   'site_detail_url': 'https://www.gamespot.com/risk/'},
#  {'release_date': '1998-03-31 12:00:00',
#   'description': "In the distant future, a small group of human exiles have been doomed to fight for survival on the edge of the galaxy. Planet resources begin to run short, and three unique species--Terran, Protoss, and Zerg--engage in intergalactic warfare. As the military leader for your species, you must gather the resources you need to train and expand your forces and lead them to victory across three different campaigns. Each species has unique units, technologies, attributes, and abilities--all of which you'll need to master for control of the galaxy.",
#   'id': 20,
#   'name': 'Starcraft',
#   'deck': "It doesn't stray far from the blueprint created by its predecessors, but it is, without a doubt, the best game to ever adhere to that formula.",
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/5/4/1/6/2215416-starcraft_box_art.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/5/4/1/6/2215416-starcraft_box_art.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/5/4/1/6/2215416-starcraft_box_art.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/5/4/1/6/2215416-starcraft_box_art.jpg'},
#   'genres': [{'name': 'Real-Time'}, {'name': 'Strategy'}],
#   'themes': [{'name': 'Sci-Fi'}],
#   'franchises': [{'name': 'Starcraft'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-20',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-20',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-20',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-20',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-20',
#   'site_detail_url': 'https://www.gamespot.com/starcraft/'},
#  {'release_date': '2003-02-25 12:00:00',
#   'description': "No longer do you represent mere interplanetary dictators. In Master of Orion 3, you become the controlling force behind an entire galactic civilization. You'll explore solar systems, complete with jump lanes, wormholes, and hostile alien races, and take part in large battles. Crush your enemies with oppressive force or negotiate to scheme your way to the top. It is not enough to be an able economist or a great captain to succeed. Political, administrative, and espionage skills must be applied to craft your civilization's glorious chapter in the annals of time and space to claim the rightful title of Master of Orion.",
#   'id': 21,
#   'name': 'Master of Orion 3',
#   'deck': 'Master of Orion III is a disappointing follow-up to the two most significant space empire games ever.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/box/1/3/1/21-131.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/box/1/3/1/21-131.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/box/1/3/1/21-131.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/box/1/3/1/21-131.jpg'},
#   'genres': [{'name': 'Strategy'}, {'name': 'Turn-Based'}],
#   'themes': [{'name': 'Sci-Fi'}],
#   'franchises': [{'name': 'Master of Orion'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-21',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-21',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-21',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-21',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-21',
#   'site_detail_url': 'https://www.gamespot.com/master-of-orion-3/'},
#  {'release_date': '1996-10-31 12:00:00',
#   'description': 'Climb, swim, and backflip your way through a maze of cryptic deathtraps so realistic you can practically smell the decaying flesh. Unload an arsenal of lethal firepower on any wild-dog, giant lizard or blood-thirsty mercenary that gets in your way.\r\nYour mission is the deadliest one to date -- the recovery of the fabled Scion, an incredible treasure reputed to give its possessor vast power. Get ready to cross the globe to take on impossible odds while exploring Incan ruins, Ancient Rome, Egyptian Pyramids, and the Lost City of Atlantis...',
#   'id': 22,
#   'name': 'Tomb Raider (1996)',
#   'deck': 'Tomb Raider is simply a smart game, bursting with great touches.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/box/1/3/4/22-134.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/box/1/3/4/22-134.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/box/1/3/4/22-134.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/box/1/3/4/22-134.jpg'},
#   'genres': [{'name': 'Action'}, {'name': 'Adventure'}],
#   'themes': [{'name': 'Modern'}],
#   'franchises': [{'name': 'Tomb Raider'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-22',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-22',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-22',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-22',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-22',
#   'site_detail_url': 'https://www.gamespot.com/tomb-raider-1996/'},
#  {'release_date': '1997-10-31 12:00:00',
#   'description': 'I\'ve sailed the seas from Trinidad to Tortuga and I\'ve never seen anything like it! The engagement ring I gave Elaine has a terrible pirate curse on it. LeChuck is behind it, I\'m sure. I should have known that nothing good could come out of that evil zombie\'s treasures. And if that\'s not bad enough, the clairvoyant I met in the mangrove swamp told me that if I am to break the curse and save Elaine, I will have to die!\r\n-Excerpted from "The Memoirs of Guybrush Threepwood: The Monkey Island Years"\r\n- Third in the legendary Monkey Island series of graphic adventures\r\n- Film quality animation, voice, sound and music--the undead come to life before your very eyes!\r\n- Incredible high-resolution (640 x 480) graphics!\r\n- A barrel of gameplay--estimated 30-plus hours!\r\n- Two difficulty settings: regular and Mega-Monkey (now with more puzzley goodness)!\r\n- New and improved insults suitable for swordfights and other fun occasions!',
#   'id': 23,
#   'name': 'The Curse of Monkey Island',
#   'deck': 'Like its predecessors, The Curse of Monkey Island has all the makings of a classic.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/1/6/7/1/2211671-curse_of_monkey_island_box_front_6552x8298.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/1/6/7/1/2211671-curse_of_monkey_island_box_front_6552x8298.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/1/6/7/1/2211671-curse_of_monkey_island_box_front_6552x8298.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/1/6/7/1/2211671-curse_of_monkey_island_box_front_6552x8298.jpg'},
#   'genres': [{'name': 'Adventure'}],
#   'themes': [],
#   'franchises': [{'name': 'Monkey Island'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-23',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-23',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-23',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-23',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-23',
#   'site_detail_url': 'https://www.gamespot.com/the-curse-of-monkey-island/'},
#  {'release_date': '1997-02-28 12:00:00',
#   'description': "It's 1976... a different '76. Stretched out before you are thousands of miles of desert -- the American Southwest. The massive engine roars as you slam down the accelerator. It's time to get funked up...\r\n\r\nYou are Groove Champion, auto-vigilante. Your agenda: Payback for your dead sister. Your weapon: A 425-horsepower '72 Picard Piranha with two 50-caliber M60 machine gun on top and a flame-thrower on the side. You're one mean dude with an even meaner ride.\r\n\r\nThey've messed with the wrong Champion.",
#   'id': 24,
#   'name': "Interstate '76",
#   'deck': "Interstate '76 is an incredible gaming experience and offers countless hours of enjoyment for those who are willing to face up to its challenge.",
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/1/4/2/1/2211421-i76_cover_small.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/1/4/2/1/2211421-i76_cover_small.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/1/4/2/1/2211421-i76_cover_small.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/1/4/2/1/2211421-i76_cover_small.jpg'},
#   'genres': [{'name': 'Simulation'}],
#   'themes': [],
#   'franchises': [{'name': "Interstate '76 / Vigilante 8"}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-24',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-24',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-24',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-24',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-24',
#   'site_detail_url': 'https://www.gamespot.com/interstate-76/'},
#  {'release_date': '1996-11-30 12:00:00',
#   'description': '',
#   'id': 25,
#   'name': 'NASCAR Racing 2',
#   'deck': 'Allow me to make one crucial point: NASCAR 2 is not a toy.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/9/9/6/5/2209965-nascar2_cover.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/9/9/6/5/2209965-nascar2_cover.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/9/9/6/5/2209965-nascar2_cover.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/9/9/6/5/2209965-nascar2_cover.jpg'},
#   'genres': [{'name': 'Driving/Racing'}, {'name': 'Simulation'}],
#   'themes': [],
#   'franchises': [{'name': 'NASCAR Racing'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-25',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-25',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-25',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-25',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-25',
#   'site_detail_url': 'https://www.gamespot.com/nascar-racing-2/'},
#  {'release_date': '1996-08-31 12:00:00',
#   'description': 'The Elder Scrolls: Daggerfall is the second chapter in the highly acclaimed Elder Scrolls role-playing series. Its predecessor, TES: Arena, won over twenty Best Role Playing Game of the Year awards and set a new level for computer role playing. TES: Daggerfall is the most ambitious CRPG ever created and surpasses the high standard set in Arena.\r\n\r\nDaggerfall offers you an opportunity to adventure in total freedom within a world where your destiny is of your own making and consequence evolves from your decisions. A world of love and darkness, magic and sorcery. Whether you choose to follow a quest or to venture out alone, you will interact with thousands of people as you travel across an expansive land in a time of fantasy and imagination.',
#   'id': 26,
#   'name': 'The Elder Scrolls: Chapter II - Daggerfall',
#   'deck': 'Someone has finally returned to the RPGs of the old school and created an adventure that will take even the most experienced gamer months to unravel.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/box/1/5/9/26-159.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/box/1/5/9/26-159.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/box/1/5/9/26-159.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/box/1/5/9/26-159.jpg'},
#   'genres': [{'name': 'Role-Playing'}],
#   'themes': [],
#   'franchises': [{'name': 'The Elder Scrolls'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-26',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-26',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-26',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-26',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-26',
#   'site_detail_url': 'https://www.gamespot.com/the-elder-scrolls-chapter-ii-daggerfall/'},
#  {'release_date': '1996-05-31 12:00:00',
#   'description': 'As Sir Gawain, a heroic knight of the Round Table, you must be quick to uncover the plot of the wicked sorceress Morgara. Defeat here before she drives Camelot from peace and prosperity into ruin!',
#   'id': 27,
#   'name': 'Chronicles of the Sword',
#   'deck': 'Chronicles of the Sword takes a classic approach to a classic story&#151;and manages to accomplish very little in the process.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/8/6/5/3/2218653-chronicles_of_the_sword___1996___psygnosis_limited.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/8/6/5/3/2218653-chronicles_of_the_sword___1996___psygnosis_limited.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/8/6/5/3/2218653-chronicles_of_the_sword___1996___psygnosis_limited.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/8/6/5/3/2218653-chronicles_of_the_sword___1996___psygnosis_limited.jpg'},
#   'genres': [{'name': 'Adventure'}],
#   'themes': [],
#   'franchises': [],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-27',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-27',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-27',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-27',
# ...
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-95',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-95',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-95',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-95',
#   'site_detail_url': 'https://www.gamespot.com/virus-the-game/'},
#  {'release_date': '1999-09-15 12:00:00',
#   'description': 'Finally, a starship combat game worthy of the name Star Trek.\nStar Trek: Starfleet Command puts you in the captain\'s chair for an amazing real-time space combat experience.\n\nDozens of missions & more than 50 ship designs put you in the captain\'s chair for an amazing real-time space combat experience commanding ships from the United Federation of Planets, the Klingon Empire, the Romulan Star Empire, the Hydran Kingdom, the Gorn Confederation or the Lyran Star Empire! \n\nPledge your allegiance to the United Federation of Planets, the Klingon Empire, the Romulan Star Empire, the Hydran Kingdom, the Gorn Confederation or the Lyran Star Empire.\n\nEvery good tactician knows there\'s a fine balance between speed and raw power. Choose from four classes of ships and over 50 3-D rendered hull designs.\n\nExperience a 30-year campaign that takes you from Lieutenant Commander of a Frigate to a Rear Admiral in control of a task force including Destroyers, Heavy Cruisers and Dreadnoughts.\n\nMulti-function display panels offer instant access to critical systems: Sensors, Weapons, Shields, Transporters, Marines, Mines, Engineering, Science and Energy Management.\n\nChallenge yourself with dozens of unique missions created by the Dynaverse engine or re-enact classic scenarios from the Original Series.\n\nNumerous multi-player options include "Pass the Tribble" and cooperative Starbase Assault with up to six players. Or go head-to-head over various network connections.',
#   'id': 96,
#   'name': 'Star Trek: Starfleet Command',
#   'deck': 'Starfleet Command is undoubtedly the best combat-oriented Trek game yet.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/9/2/3/3/2209233-starfleetcommand.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/9/2/3/3/2209233-starfleetcommand.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/9/2/3/3/2209233-starfleetcommand.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/9/2/3/3/2209233-starfleetcommand.jpg'},
#   'genres': [{'name': 'Strategy'}],
#   'themes': [],
#   'franchises': [{'name': 'Star Trek'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-96',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-96',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-96',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-96',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-96',
#   'site_detail_url': 'https://www.gamespot.com/star-trek-starfleet-command/'},
#  {'release_date': '1996-12-03 12:00:00',
#   'description': "A long time ago in a galaxy far, far away... As Luke Skywalker and the Rebel Alliance struggle to defeat Darth Vader and the Empire, a new threat arises. Dark Prince Xizor, head of the Black Sun crime syndicate, aspires to take Darth Vader's place at the Emperor's side. To do that, he must eliminate young Skywalker. As Dash Rendar, it's up to you to protect Luke and help the Alliance defeat the evil Xizor. Watch out for infamous bounty hunters and deadly stormtroopers! May the Force be with you!",
#   'id': 97,
#   'name': 'Star Wars: Shadows of the Empire',
#   'deck': 'Problems with the control, camera angles, and frustrating save feature keep Shadows from reaching its full potential.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/4/9/5/8/2214958-star_wars___shadows_of_the_empire_coverart.png',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/4/9/5/8/2214958-star_wars___shadows_of_the_empire_coverart.png',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/4/9/5/8/2214958-star_wars___shadows_of_the_empire_coverart.png',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/4/9/5/8/2214958-star_wars___shadows_of_the_empire_coverart.png'},
#   'genres': [{'name': 'Action'}, {'name': 'Adventure'}],
#   'themes': [{'name': 'Sci-Fi'}],
#   'franchises': [{'name': 'Star Wars'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-97',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-97',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-97',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-97',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-97',
#   'site_detail_url': 'https://www.gamespot.com/star-wars-shadows-of-the-empire/'},
#  {'release_date': '1999-03-31 12:00:00',
#   'description': "You have been selected for active service in the Commandos Corps, and must now mobilize in a series of 8 new dangerous missions. You may come with experience of action 'Behind Enemy Lines' or perhaps you are just a rookie - whatever you are, you will be given the opportunity to push your daring and tactical ability to the limit.\r\nAs the leader of a small elite unit operating deep within enemy territory, you will experience new challenges and goals with these new missions. Plus new vehicles, buildings, weapons and 2 levels of difficulty will satisfy both Commandos veterans and new recruits.",
#   'id': 208,
#   'name': 'Commandos: Beyond the Call of Duty',
#   'deck': 'Beyond the Call of Duty ends up feeling like a shadow of its former self, being both shorter and more frustrating than the original.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/4/1/3/2/2214132-commando.jpeg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/4/1/3/2/2214132-commando.jpeg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/4/1/3/2/2214132-commando.jpeg',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/4/1/3/2/2214132-commando.jpeg'},
#   'genres': [{'name': 'Real-Time'}, {'name': 'Strategy'}],
#   'themes': [],
#   'franchises': [{'name': 'Commandos'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-208',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-208',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-208',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-208',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-208',
#   'site_detail_url': 'https://www.gamespot.com/commandos-beyond-the-call-of-duty/'},
#  {'release_date': '1999-08-31 12:00:00',
#   'description': "He's all that stands between us and a Time-Spanning Alien invasion. He's Duke Nukem. Gaming's Greatest Action Hero. And this is his finest hour! Zero Hour! Awesome new enemies! Hilarious gags and one-liners! Same blood and guts attitude! Over 30 gut-wrenching levels set in four action-packed time eras! Incredible Teamplay and Deathmatch modes for up to 4 players! Over 20 all-new weapons of high-octane annihilation.",
#   'id': 297,
#   'name': 'Duke Nukem: Zero Hour',
#   'deck': "He's all that stands between us and a Time-Spanning Alien invasion. He's Duke Nukem. Gaming's Greatest Action Hero. And this is his finest hour! Zero Hour!",
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/mig/0/1/0/1/2210101-box_dnzh.png',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/mig/0/1/0/1/2210101-box_dnzh.png',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/mig/0/1/0/1/2210101-box_dnzh.png',
#    'original': 'https://www.gamespot.com/a/uploads/original/mig/0/1/0/1/2210101-box_dnzh.png'},
#   'genres': [{'name': '3D'},
#    {'name': 'Action'},
#    {'name': 'Shooter'},
#    {'name': 'Third-Person'}],
#   'themes': [{'name': 'Sci-Fi'}],
#   'franchises': [{'name': 'Duke Nukem'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-297',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-297',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-297',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-297',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-297',
#   'site_detail_url': 'https://www.gamespot.com/duke-nukem-zero-hour/'},
#  {'release_date': '2010-09-21 12:00:00',
#   'description': "With over nine million units sold worldwide, and unprecedented critical acclaim from fans and press around the world, Sid Meier's Civilization is recognized as one of the greatest strategy franchises of all-time. Now, Firaxis Games will take this incredibly fun and addictive strategy game to unprecedented heights by adding new ways to play and win; new tools to manage and expand your civilization; extensive modding capabilities; and intensely competitive multiplayer options. Civilization V will come to life in a beautifully detailed, living world that will elevate the gameplay experience to a whole new level making it a must-have for gamers around the globe!",
#   'id': 30098,
#   'name': "Sid Meier's Civilization V",
#   'deck': 'Civilization V features a number of new elements, as well as the addictive gameplay that has made this empire-building series a hit.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/536/5360430/2360541-civ5.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/536/5360430/2360541-civ5.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/536/5360430/2360541-civ5.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/536/5360430/2360541-civ5.jpg'},
#   'genres': [{'name': 'Strategy'}, {'name': 'Turn-Based'}],
#   'themes': [{'name': 'Historic'}],
#   'franchises': [{'name': 'Civilization'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-30098',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-30098',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-30098',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-30098',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-30098',
#   'site_detail_url': 'https://www.gamespot.com/sid-meiers-civilization-v/'},
#  {'release_date': '2008-03-04 12:00:00',
#   'description': 'Before he waged war on the gods... he was forced to serve them.\r\n\r\nThe ancient world speaks of a mortal that slayed a God. But long before his battle with Ares, Kratos sought absolution from his past sins by pledging himself as a champion to the Gods. These brutal crusades in the name of Olympus became legendary. The Ghost of Sparta is now ordered by the Gods to journey the underworld, after the world plunges into darkness. There he must face the most feared creatures of Greek Mythology and is forced to choose between his own personal redemption and saving the ancient world from certain destruction.',
#   'id': 30151,
#   'name': 'God of War: Chains of Olympus',
#   'deck': 'Chains of Olympus sees the return of angry demigod Kratos as he hacks and slashes his way through an ultra-violent adventure on the PSP.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/1197/11970954/2428273-2219173-box_gowcoo.png',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/1197/11970954/2428273-2219173-box_gowcoo.png',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/1197/11970954/2428273-2219173-box_gowcoo.png',
#    'original': 'https://www.gamespot.com/a/uploads/original/1197/11970954/2428273-2219173-box_gowcoo.png'},
#   'genres': [{'name': 'Action'}, {'name': 'Adventure'}],
#   'themes': [{'name': 'Fantasy'}],
#   'franchises': [{'name': 'God of War'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-30151',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-30151',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-30151',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-30151',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-30151',
#   'site_detail_url': 'https://www.gamespot.com/god-of-war-chains-of-olympus/'},
#  {'release_date': '2009-02-10 12:00:00',
#   'description': "Take a trip back in time with over 40 titles from the SEGA Genesis era, including your Sonic The Hedgehog favorites. In classic single-player and multiplayer battles, you'll take down a huge variety of enemies, including Sonic's nemesis Dr. Eggman (AKA Dr. Robotnik), shuriken-flinging ninjas, hordes of altered beasts and the world's greatest fighting champions.",
#   'id': 40208,
#   'name': "Sonic's Ultimate Genesis Collection",
#   'deck': "Sonic's Ultimate Genesis Collection features over 40 titles from the SEGA Genesis era.",
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/1197/11970954/2428220-2221258-sonic.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/1197/11970954/2428220-2221258-sonic.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/1197/11970954/2428220-2221258-sonic.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/1197/11970954/2428220-2221258-sonic.jpg'},
#   'genres': [{'name': 'Compilation'}],
#   'themes': [],
#   'franchises': [{'name': 'Sonic the Hedgehog'},
#    {'name': 'Sega Genesis Classics'}],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-40208',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-40208',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-40208',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-40208',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-40208',
#   'site_detail_url': 'https://www.gamespot.com/sonics-ultimate-genesis-collection/'},
#  {'release_date': '2015-09-10 12:00:00',
#   'description': 'Otherland is a massively multiplayer online game based on the best-selling novels by fantasy author Tad Williams.',
#   'id': 40260,
#   'name': 'Otherland',
#   'deck': 'Otherland is a massively multiplayer online game based on the best-selling novels by fantasy author Tad Williams.',
#   'image': {'square_tiny': 'https://www.gamespot.com/a/uploads/square_tiny/536/5360430/2928954-untitled-2.jpg',
#    'screen_tiny': 'https://www.gamespot.com/a/uploads/screen_tiny/536/5360430/2928954-untitled-2.jpg',
#    'square_small': 'https://www.gamespot.com/a/uploads/square_small/536/5360430/2928954-untitled-2.jpg',
#    'original': 'https://www.gamespot.com/a/uploads/original/536/5360430/2928954-untitled-2.jpg'},
#   'genres': [{'name': 'MMO'}, {'name': 'Role-Playing'}],
#   'themes': [{'name': 'Fantasy'}],
#   'franchises': [],
#   'images_api_url': 'https://www.gamespot.com/api/images/?filter=association:5000-40260',
#   'reviews_api_url': 'https://www.gamespot.com/api/reviews/?filter=association:5000-40260',
#   'articles_api_url': 'https://www.gamespot.com/api/articles/?filter=association:5000-40260',
#   'videos_api_url': 'https://www.gamespot.com/api/videos/?filter=association:5000-40260',
#   'releases_api_url': 'https://www.gamespot.com/api/releases/?filter=association:5000-40260',
#   'site_detail_url': 'https://www.gamespot.com/otherland/'}]

# %%
def gitgames(limit = 100, offset=0):  
    params.setdefault('limit', limit)
    params.setdefault('offset', offset)

    
    try: 
        url = "https://www.gamespot.com/api/games/"
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()
        data = response.json ()
        return(data)
    except requests.exceptions.HTTPError as http_err:
        print (f"HTTP error occurred: {http_err}")
    except Exception as err:
        print(f"Other error occurred: {err}")

# %%
offset = 0
total_results = 1


while offset < total_results : 
    data = gitgames(limit = 100, offset=offset)    
    total_results = data.get('number_of_total_results')
    print (offset, end='\r')
    if offset == 0 : 
        games_df = pd.DataFrame(data['results'])
    else : 
        games_df = pd.concat ([games_df, pd.DataFrame(data['results'])], axis=0)
    offset = offset + 100

# %%
games_df.reset_index(drop=True, inplace=True)

# %%
games_df.describe()

# %%
games_df.head()

# %%
len(games_df)

# %%
games_df.tail()

# %%
#df is your dataframe
games_df.to_csv("gamespot_games.csv", sep=',', encoding='utf-8', index=False)

# %%
def getReviews(limit = 100, offset=0):  
    params.setdefault('limit', limit)
    params.setdefault('offset', offset)

    
    try: 
        url = 'http://www.gamespot.com/api/reviews/'
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()
        data = response.json ()
        return(data)
    except requests.exceptions.HTTPError as http_err:
        print (f"HTTP error occurred: {http_err}")
    except Exception as err:
        print(f"Other error occurred: {err}")

# %%
offset = 0
total_results = 1


while offset < total_results : 
    data = getReviews(limit = 100, offset=offset)    
    total_results = data.get('number_of_total_results')
    print (f'{offset}/{total_results}', end='\r')
    if offset == 0 : 
        review_df = pd.DataFrame(data['results'])
    else : 
        review_df = pd.concat ([review_df, pd.DataFrame(data['results'])], axis=0)
    offset = offset + 100
# Out:
# 15800

# %%
review_df.reset_index(drop=True, inplace=True)

# %%
review_df.tail()

# %%
review_df['authors'].value_counts()
# Out:
# Gamespot Staff      2703
# Jeffrey Adam        2544
# Hugo Foster         2226
# Chris Hudak         2067
# Ron Dulin           1908
# Trent Ward          1590
# Jeff Sengstack       795
# Tim McDonald         636
# Tal Blevins          477
# Jim Varner           318
# Stephen Poole        159
# Rebecca Anderson     159
# Tim Soete            159
# Kevin Mical          159
# Name: authors, dtype: int64

# %%
review_df[['game_title', 'game_id']] = review_df['game'].apply(lambda x: pd.Series([x['name'], x['id']]))

# %%
review_df['id'].value_counts()

# %%
len(review_df)

# %%
games_df.head()

# %%
games_df.rename(columns={'id': 'game_id'}, inplace=True)
games_df.head()

# %%
review_df['title'].value_counts()

# %%
review_df['authors'].value_counts()

# %%
game_reviews = review_df.join(games_df, lsuffix='_rev', on='game_id', how='inner')

# %%
# set max columns to display as none    
# pd.set_option('display.max_columns', None)

display(game_reviews['game_id'].value_counts())

# %%
len(game_reviews)

# %%
game_reviews.to_csv("data/gamespot_reviews.csv", sep=',', encoding='utf-8', index=False)

# %%
game_reviews.columns

# %%
game_reviews.drop(columns=['review_id', 'game_id_rev', 'game_id', 'publish_date',
    'site_detail_url', 'game_id_rev', 'videos_api_url', 'articles_api_url', 'reviews_api_url',
    'images_api_url', 'releases_api_url', 'image', 'image_rev', 'deck_rev',
    'site_detail_url_rev', 'deck', 'update_date', 'review_type',  
    'release_date', 'name', 'lede', 'title', 'good', 'bad', 'body',
    'game', 'franchises'
    ], inplace=True)

# %%
game_reviews.drop(columns=['description'], inplace=True)

game_reviews.columns

# %%
game_reviews.reset_index(drop=True, inplace=True)

# %%
game_reviews.head()

# %%
game_reviews['releases'][0]

# %%
def getPlatforms (x):

    platforms = []

    try:
        for i in range(len(x)):
            if x[i]['platform'] not in platforms:
                platforms.append(x[i]['platform'])
    except:
        return []
    return platforms

# %%
game_reviews['platforms'] = game_reviews['releases'].apply(lambda x: getPlatforms(x))

# %%
game_reviews_bak = game_reviews.copy()

# %%
def getGenres (x):

    genres = []

    try:
        for i in range(len(x)):
            if x[i]['name'] not in genres:
                genres.append(x[i]['name'])
    except:
        return []
    return genres

# %%
game_reviews['genres'] = game_reviews['genres'].apply(lambda x: getGenres(x))

# %%
game_reviews

# %%
def getThemes (x):

    themes = []

    try:
        for i in range(len(x)):
            if x[i]['name'] not in themes:
                themes.append(x[i]['name'])
    except:
        return []
    return themes

# %%
game_reviews['themes'] = game_reviews['themes'].apply(lambda x: getThemes(x))

# %%
game_reviews.drop(columns=['releases'], inplace=True)

# %%
game_reviews

# %%
game_reviews_bak1 = game_reviews.copy()

# %%
game_reviews = game_reviews_bak1.copy()

# %%
game_reviews['genres'].value_counts()

# %%
game_reviews.to_csv("data/gamespot_reviews.csv", sep=',', encoding='utf-8', index=False)

# %%
game_reviews.drop(columns=['releases'], inplace=True)

# %%
game_reviews.isna().sum()

# %%
game_reviews.dtypes

# %%
# change score dtype to float
game_reviews['score'] = game_reviews['score'].astype(float)

# %%
game_pivot = game_reviews.pivot_table(index='game_title', columns='authors', values='score')

# %%
game_pivot.fillna(0, inplace=True)
game_pivot.describe()

# %%
from scipy.sparse import csr_matrix

# %%
game_reviews_bak = game_reviews.copy()

# %%
# set max display rows to none
pd.set_option('display.max_rows', None)

game_reviews[['game_title', 'authors']].value_counts()

# %%
game_reviews['genres'].value_counts()

# %%
game_reviews['game_title'].value_counts()

# %%
game_reviews['themes'].value_counts()

# %%
game_reviews['platforms'].value_counts()

# %%
game_reviews[['authors', 'game_title']].drop_duplicates(inplace=True)

# %%
game_reviews.drop_duplicates(subset=['authors', 'game_title'], inplace=True)

# %%
review_number = game_reviews.groupby('game_title')['authors'].count().reset_index()
review_number.rename(columns={'authors': 'number_of_reviews'}, inplace=True)

display(review_number.head())
display(review_number.tail())

# %%
display(review_number.describe())

# %%
game_sparse = csr_matrix(game_pivot)

# %%
from sklearn.neighbors import NearestNeighbors
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

knn_ball_tree = NearestNeighbors(n_neighbors=5, algorithm='ball_tree')
knn_brute = NearestNeighbors(algorithm='brute')

X = game_sparse
y = game_sparse

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

knn_ball_tree.fit(X_train)

y_ball_tree = knn_ball_tree.kneighbors(X_test)
