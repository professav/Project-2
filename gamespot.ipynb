# %%
import os
from dotenv import load_dotenv
from requests import get
import requests 
import json
import pandas as pd

# %%
load_dotenv()
url = 'http://www.gamespot.com/api/games/?'
API_KEY = os.getenv('GAMESPOT_API_KEY')

# %% [markdown]
# headers = {
#     'User-Agent' : 'project1',
# }

# %%
params = {
    'api_key': API_KEY,
    'format': 'json'
}

headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36',
    'content-type': 'application/json; charset=utf-8',
    'Accept': '*/*',
    'Connection': 'keep-alive'
}

# %%
res = get(url=url, params=params,headers=headers)
print(res)
# Out:
# <Response [200]>

# %%
def gitgames(limit = 100, offset=0):  
    params.setdefault('limit', limit)
    params.setdefault('offset', offset)

    
    try: 
        url = "https://www.gamespot.com/api/games/"
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()
        data = response.json ()
        return(data)
    except requests.exceptions.HTTPError as http_err:
        print (f"HTTP error occurred: {http_err}")
    except Exception as err:
        print(f"Other error occurred: {err}")

# %%
offset = 0
total_results = 1


while offset < total_results : 
    data = gitgames(limit = 100, offset=offset)    
    total_results = data.get('number_of_total_results')
    print (offset, end='\r')
    if offset == 0 : 
        games_df = pd.DataFrame(data['results'])
    else : 
        games_df = pd.concat ([games_df, pd.DataFrame(data['results'])], axis=0)
    offset = offset + 100
# Out:
# 232000

# %%
games_df.reset_index(drop=True, inplace=True)

# %%
games_df.describe()
# Out:
#                   id
# count  231900.000000
# mean     1458.260000
# std      6957.243327
# min         1.000000
# 25%        25.750000
# 50%        52.500000
# 75%        77.250000
# max     40260.000000

# %%
games_df.head()
# Out:
#           release_date                                        description  id  \
# 0  1995-09-26 12:00:00  Welcome to the New World Order. A gritty high ...   1
# 1  1996-03-31 12:00:00  Relive those carefree and exciting days when e...   2
# 2  1995-11-30 12:00:00  From the combined talents of LucasArts and leg...   3
# 3  1995-11-30 12:00:00                                                      4
# 4  1996-06-30 12:00:00                                                      5
#
#                                        name  \
# 0                         Command & Conquer
# 1                          Return of Arcade
# 2                                   The Dig
# 3                          Mission Critical
# 4  Links LS: Legends in Sports 1997 Edition
#
#                                                 deck  \
# 0  Overall Command & Conquer is a great strategy ...
# 1  For nostalgia buffs, these old games are worth...
# 2  In almost every sense, The Dig represents a le...
# 3  Put simply, Mission Critical was one of the be...
# 4  With this update, Links LS can rightfully recl...
#
#                                                image  \
# 0  {'square_tiny': 'https://www.gamespot.com/a/up...
# 1  {'square_tiny': 'https://www.gamespot.com/a/up...
# 2  {'square_tiny': 'https://www.gamespot.com/a/up...
# 3  {'square_tiny': 'https://www.gamespot.com/a/up...
# 4  {'original': 'https://www.gamespot.com/a/uploa...
#
#                                               genres                themes  \
# 0      [{'name': 'Real-Time'}, {'name': 'Strategy'}]  [{'name': 'Sci-Fi'}]
# 1                          [{'name': 'Compilation'}]                    []
# 2                            [{'name': 'Adventure'}]                    []
# 3                            [{'name': 'Adventure'}]                    []
# 4  [{'name': 'Golf'}, {'name': 'Simulation'}, {'n...                    []
#
#                         franchises  \
# 0  [{'name': 'Command & Conquer'}]
# 1   [{'name': 'Microsoft Arcade'}]
# 2                               []
# 3                               []
# 4         [{'name': 'Links Golf'}]
#
#                                       images_api_url  \
# 0  https://www.gamespot.com/api/images/?filter=as...
# 1  https://www.gamespot.com/api/images/?filter=as...
# 2  https://www.gamespot.com/api/images/?filter=as...
# 3  https://www.gamespot.com/api/images/?filter=as...
# 4  https://www.gamespot.com/api/images/?filter=as...
#
#                                      reviews_api_url  \
# 0  https://www.gamespot.com/api/reviews/?filter=a...
# 1  https://www.gamespot.com/api/reviews/?filter=a...
# 2  https://www.gamespot.com/api/reviews/?filter=a...
# 3  https://www.gamespot.com/api/reviews/?filter=a...
# 4  https://www.gamespot.com/api/reviews/?filter=a...
#
#                                     articles_api_url  \
# 0  https://www.gamespot.com/api/articles/?filter=...
# 1  https://www.gamespot.com/api/articles/?filter=...
# 2  https://www.gamespot.com/api/articles/?filter=...
# 3  https://www.gamespot.com/api/articles/?filter=...
# 4  https://www.gamespot.com/api/articles/?filter=...
#
#                                       videos_api_url  \
# 0  https://www.gamespot.com/api/videos/?filter=as...
# 1  https://www.gamespot.com/api/videos/?filter=as...
# 2  https://www.gamespot.com/api/videos/?filter=as...
# 3  https://www.gamespot.com/api/videos/?filter=as...
# 4  https://www.gamespot.com/api/videos/?filter=as...
#
#                                     releases_api_url  \
# 0  https://www.gamespot.com/api/releases/?filter=...
# 1  https://www.gamespot.com/api/releases/?filter=...
# 2  https://www.gamespot.com/api/releases/?filter=...
# 3  https://www.gamespot.com/api/releases/?filter=...
# 4  https://www.gamespot.com/api/releases/?filter=...
#
#                                      site_detail_url
# 0      https://www.gamespot.com/command-and-conquer/
# 1         https://www.gamespot.com/return-of-arcade/
# 2                  https://www.gamespot.com/the-dig/
# 3         https://www.gamespot.com/mission-critical/
# 4  https://www.gamespot.com/links-ls-legends-in-s...

# %%
len(games_df)
# Out:
# 232100

# %%
games_df.tail()
# Out:
#                release_date  \
# 232095  1999-08-31 12:00:00
# 232096  2010-09-21 12:00:00
# 232097  2008-03-04 12:00:00
# 232098  2009-02-10 12:00:00
# 232099  2015-09-10 12:00:00
#
#                                               description     id  \
# 232095  He's all that stands between us and a Time-Spa...    297
# 232096  With over nine million units sold worldwide, a...  30098
# 232097  Before he waged war on the gods... he was forc...  30151
# 232098  Take a trip back in time with over 40 titles f...  40208
# 232099  Otherland is a massively multiplayer online ga...  40260
#
#                                        name  \
# 232095                Duke Nukem: Zero Hour
# 232096           Sid Meier's Civilization V
# 232097        God of War: Chains of Olympus
# 232098  Sonic's Ultimate Genesis Collection
# 232099                            Otherland
#
#                                                      deck  \
# 232095  He's all that stands between us and a Time-Spa...
# 232096  Civilization V features a number of new elemen...
# 232097  Chains of Olympus sees the return of angry dem...
# 232098  Sonic's Ultimate Genesis Collection features o...
# 232099  Otherland is a massively multiplayer online ga...
#
#                                                     image  \
# 232095  {'square_tiny': 'https://www.gamespot.com/a/up...
# 232096  {'square_tiny': 'https://www.gamespot.com/a/up...
# 232097  {'square_tiny': 'https://www.gamespot.com/a/up...
# 232098  {'square_tiny': 'https://www.gamespot.com/a/up...
# 232099  {'square_tiny': 'https://www.gamespot.com/a/up...
#
#                                                    genres  \
# 232095  [{'name': '3D'}, {'name': 'Action'}, {'name': ...
# 232096     [{'name': 'Strategy'}, {'name': 'Turn-Based'}]
# 232097        [{'name': 'Action'}, {'name': 'Adventure'}]
# 232098                          [{'name': 'Compilation'}]
# 232099        [{'name': 'MMO'}, {'name': 'Role-Playing'}]
#
#                         themes  \
# 232095    [{'name': 'Sci-Fi'}]
# 232096  [{'name': 'Historic'}]
# 232097   [{'name': 'Fantasy'}]
# 232098                      []
# 232099   [{'name': 'Fantasy'}]
#
#                                                franchises  \
# 232095                           [{'name': 'Duke Nukem'}]
# 232096                         [{'name': 'Civilization'}]
# 232097                           [{'name': 'God of War'}]
# 232098  [{'name': 'Sonic the Hedgehog'}, {'name': 'Seg...
# 232099                                                 []
#
#                                            images_api_url  \
# 232095  https://www.gamespot.com/api/images/?filter=as...
# 232096  https://www.gamespot.com/api/images/?filter=as...
# 232097  https://www.gamespot.com/api/images/?filter=as...
# 232098  https://www.gamespot.com/api/images/?filter=as...
# 232099  https://www.gamespot.com/api/images/?filter=as...
#
#                                           reviews_api_url  \
# 232095  https://www.gamespot.com/api/reviews/?filter=a...
# 232096  https://www.gamespot.com/api/reviews/?filter=a...
# 232097  https://www.gamespot.com/api/reviews/?filter=a...
# 232098  https://www.gamespot.com/api/reviews/?filter=a...
# 232099  https://www.gamespot.com/api/reviews/?filter=a...
#
#                                          articles_api_url  \
# 232095  https://www.gamespot.com/api/articles/?filter=...
# 232096  https://www.gamespot.com/api/articles/?filter=...
# 232097  https://www.gamespot.com/api/articles/?filter=...
# 232098  https://www.gamespot.com/api/articles/?filter=...
# 232099  https://www.gamespot.com/api/articles/?filter=...
#
#                                            videos_api_url  \
# 232095  https://www.gamespot.com/api/videos/?filter=as...
# 232096  https://www.gamespot.com/api/videos/?filter=as...
# 232097  https://www.gamespot.com/api/videos/?filter=as...
# 232098  https://www.gamespot.com/api/videos/?filter=as...
# 232099  https://www.gamespot.com/api/videos/?filter=as...
#
#                                          releases_api_url  \
# 232095  https://www.gamespot.com/api/releases/?filter=...
# 232096  https://www.gamespot.com/api/releases/?filter=...
# 232097  https://www.gamespot.com/api/releases/?filter=...
# 232098  https://www.gamespot.com/api/releases/?filter=...
# 232099  https://www.gamespot.com/api/releases/?filter=...
#
#                                           site_detail_url
# 232095     https://www.gamespot.com/duke-nukem-zero-hour/
# 232096  https://www.gamespot.com/sid-meiers-civilizati...
# 232097  https://www.gamespot.com/god-of-war-chains-of-...
# 232098  https://www.gamespot.com/sonics-ultimate-genes...
# 232099                https://www.gamespot.com/otherland/

# %%
#df is your dataframe
games_df.to_csv("gamespot_games.csv", sep=',', encoding='utf-8', index=False)

# %%
def getReviews(limit = 100, offset=0):  
    params.setdefault('limit', limit)
    params.setdefault('offset', offset)

    
    try: 
        url = 'http://www.gamespot.com/api/reviews/'
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()
        data = response.json ()
        return(data)
    except requests.exceptions.HTTPError as http_err:
        print (f"HTTP error occurred: {http_err}")
    except Exception as err:
        print(f"Other error occurred: {err}")

# %%
offset = 0
total_results = 1


while offset < total_results : 
    data = getReviews(limit = 100, offset=offset)    
    total_results = data.get('number_of_total_results')
    print (offset, end='\r')
    if offset == 0 : 
        review_df = pd.DataFrame(data['results'])
    else : 
        review_df = pd.concat ([review_df, pd.DataFrame(data['results'])], axis=0)
    offset = offset + 100
# Out:
# 15800

# %%
review_df.reset_index(drop=True, inplace=True)

# %%
review_df.tail()
# Out:
#               publish_date          update_date review_type       id  \
# 15895  1996-05-01 12:00:00  2000-05-02 11:52:08     primary  2559962
# 15896  1996-05-01 12:00:00  2000-05-02 11:52:34     primary  2559963
# 15897  1996-05-01 12:00:00  2000-05-02 12:00:05     primary  2560015
# 15898  1996-05-01 12:00:00  2000-05-09 02:16:43     primary  2565949
# 15899  1996-05-01 12:00:00  1996-05-01 12:00:00     primary  2565964
#
#             authors                    title  \
# 15895  Jeffrey Adam   Torin's Passage Review
# 15896   Chris Hudak  Total Distortion Review
# 15897     Ron Dulin              Zoop Review
# 15898  Jeffrey Adam            Ripper Review
# 15899   Kevin Mical    Steel Panthers Review
#
#                                                    image score  \
# 15895  {'square_tiny': 'https://www.gamespot.com/a/up...   7.0
# 15896  {'square_tiny': 'https://www.gamespot.com/a/up...   6.4
# 15897  {'square_tiny': 'https://www.gamespot.com/a/up...   7.0
# 15898  {'square_tiny': 'https://www.gamespot.com/a/up...   3.6
# 15899  {'square_tiny': 'https://www.gamespot.com/a/up...   8.4
#
#                                                     deck good bad  \
# 15895  In his latest project, Torin's Passage, Lowe h...
# 15896  From the initial concept to the game-over sequ...
# 15897  Once you do break through the initial frustrat...
# 15898  The cast of Take 2 Interactive's Ripper is stu...
# 15899  Steel Panthers is your chance to recreate some...
#
#                                                     body  \
# 15895  <p>Sierra has been perfecting their brand of c...
# 15896  From the initial concept to the game-over sequ...
# 15897  <p>Tetris has remained the king of puzzle game...
# 15898  <p>Christopher Walken, Burgess Meredith, Karen...
# 15899  <p>Think General Patton was a wimp? Feel you c...
#
#                                                     lede  \
# 15895  In his latest project, Torin's Passage, Lowe h...
# 15896  From the initial concept to the game-over sequ...
# 15897  Once you do break through the initial frustrat...
# 15898  The cast of Take 2 Interactive's Ripper is stu...
# 15899  Steel Panthers is your chance to recreate some...
#
#                                                     game  \
# 15895  {'id': 2168, 'name': 'Torin's Passage', 'api_d...
# 15896  {'id': 2176, 'name': 'Total Distortion', 'api_...
# 15897  {'id': 2388, 'name': 'Zoop', 'api_detail_url':...
# 15898  {'id': 1743, 'name': 'Ripper (1996)', 'api_det...
# 15899  {'id': 1971, 'name': 'Steel Panthers', 'api_de...
#
#                                                 releases  \
# 15895  [{'upc': None, 'distribution_type': 'Retail', ...
# 15896  [{'upc': None, 'distribution_type': 'Retail', ...
# 15897  [{'upc': None, 'distribution_type': 'Retail', ...
# 15898  [{'upc': None, 'distribution_type': 'Retail', ...
# 15899  [{'upc': None, 'distribution_type': 'Retail', ...
#
#                                          site_detail_url
# 15895  https://www.gamespot.com/reviews/torins-passag...
# 15896  https://www.gamespot.com/reviews/total-distort...
# 15897  https://www.gamespot.com/reviews/zoop-review/1...
# 15898  https://www.gamespot.com/reviews/ripper-review...
# 15899  https://www.gamespot.com/reviews/steel-panther...

# %%
review_df['authors'].value_counts()
# Out:
# authors
# Gamespot Staff      2703
# Jeffrey Adam        2544
# Hugo Foster         2226
# Chris Hudak         2067
# Ron Dulin           1908
# Trent Ward          1590
# Jeff Sengstack       795
# Tim McDonald         636
# Tal Blevins          477
# Jim Varner           318
# Stephen Poole        159
# Rebecca Anderson     159
# Tim Soete            159
# Kevin Mical          159
# Name: count, dtype: int64

# %%
review_df[['game_title', 'game_id']] = review_df['game'].apply(lambda x: pd.Series([x['name'], x['id']]))

# %%
review_df['id'].value_counts()
# Out:
# id
# 2531694    159
# 2538477    159
# 2540101    159
# 2540098    159
# 2540085    159
#           ...
# 2535791    159
# 2535699    159
# 2535527    159
# 2535437    159
# 2565964    159
# Name: count, Length: 100, dtype: int64

# %%
len(review_df)
# Out:
# 15900

# %%
games_df.head()

# %%
games_df.rename(columns={'id': 'game_id'}, inplace=True)
games_df.head()
# Out:
#           release_date                                        description  \
# 0  1995-09-26 12:00:00  Welcome to the New World Order. A gritty high ...
# 1  1996-03-31 12:00:00  Relive those carefree and exciting days when e...
# 2  1995-11-30 12:00:00  From the combined talents of LucasArts and leg...
# 3  1995-11-30 12:00:00
# 4  1996-06-30 12:00:00
#
#    game_id                                      name  \
# 0        1                         Command & Conquer
# 1        2                          Return of Arcade
# 2        3                                   The Dig
# 3        4                          Mission Critical
# 4        5  Links LS: Legends in Sports 1997 Edition
#
#                                                 deck  \
# 0  Overall Command & Conquer is a great strategy ...
# 1  For nostalgia buffs, these old games are worth...
# 2  In almost every sense, The Dig represents a le...
# 3  Put simply, Mission Critical was one of the be...
# 4  With this update, Links LS can rightfully recl...
#
#                                                image  \
# 0  {'square_tiny': 'https://www.gamespot.com/a/up...
# 1  {'square_tiny': 'https://www.gamespot.com/a/up...
# 2  {'square_tiny': 'https://www.gamespot.com/a/up...
# 3  {'square_tiny': 'https://www.gamespot.com/a/up...
# 4  {'original': 'https://www.gamespot.com/a/uploa...
#
#                                               genres                themes  \
# 0      [{'name': 'Real-Time'}, {'name': 'Strategy'}]  [{'name': 'Sci-Fi'}]
# 1                          [{'name': 'Compilation'}]                    []
# 2                            [{'name': 'Adventure'}]                    []
# 3                            [{'name': 'Adventure'}]                    []
# 4  [{'name': 'Golf'}, {'name': 'Simulation'}, {'n...                    []
#
#                         franchises  \
# 0  [{'name': 'Command & Conquer'}]
# 1   [{'name': 'Microsoft Arcade'}]
# 2                               []
# 3                               []
# 4         [{'name': 'Links Golf'}]
#
#                                       images_api_url  \
# 0  https://www.gamespot.com/api/images/?filter=as...
# 1  https://www.gamespot.com/api/images/?filter=as...
# 2  https://www.gamespot.com/api/images/?filter=as...
# 3  https://www.gamespot.com/api/images/?filter=as...
# 4  https://www.gamespot.com/api/images/?filter=as...
#
#                                      reviews_api_url  \
# 0  https://www.gamespot.com/api/reviews/?filter=a...
# 1  https://www.gamespot.com/api/reviews/?filter=a...
# 2  https://www.gamespot.com/api/reviews/?filter=a...
# 3  https://www.gamespot.com/api/reviews/?filter=a...
# 4  https://www.gamespot.com/api/reviews/?filter=a...
#
#                                     articles_api_url  \
# 0  https://www.gamespot.com/api/articles/?filter=...
# 1  https://www.gamespot.com/api/articles/?filter=...
# 2  https://www.gamespot.com/api/articles/?filter=...
# 3  https://www.gamespot.com/api/articles/?filter=...
# 4  https://www.gamespot.com/api/articles/?filter=...
#
#                                       videos_api_url  \
# 0  https://www.gamespot.com/api/videos/?filter=as...
# 1  https://www.gamespot.com/api/videos/?filter=as...
# 2  https://www.gamespot.com/api/videos/?filter=as...
# 3  https://www.gamespot.com/api/videos/?filter=as...
# 4  https://www.gamespot.com/api/videos/?filter=as...
#
#                                     releases_api_url  \
# 0  https://www.gamespot.com/api/releases/?filter=...
# 1  https://www.gamespot.com/api/releases/?filter=...
# 2  https://www.gamespot.com/api/releases/?filter=...
# 3  https://www.gamespot.com/api/releases/?filter=...
# 4  https://www.gamespot.com/api/releases/?filter=...
#
#                                      site_detail_url
# 0      https://www.gamespot.com/command-and-conquer/
# 1         https://www.gamespot.com/return-of-arcade/
# 2                  https://www.gamespot.com/the-dig/
# 3         https://www.gamespot.com/mission-critical/
# 4  https://www.gamespot.com/links-ls-legends-in-s...

# %%
game_reviews = review_df.join(games_df, lsuffix='_rev', on='game_id', how='inner')

# %%
# set max columns to display as none    
# pd.set_option('display.max_columns', None)

display(game_reviews['game_id'].value_counts())
# Out:
# game_id
# 15       636
# 48       636
# 13       636
# 71       477
# 55       477
#         ...
# 29       159
# 40208    159
# 83       159
# 90       159
# 79       159
# Name: count, Length: 63, dtype: int64

# %%
len(game_reviews)
# Out:
# 15741

# %%
game_reviews.to_csv("data/gamespot_reviews.csv", sep=',', encoding='utf-8', index=False)

# %%
game_reviews.columns
# Out:
# Index(['publish_date', 'update_date', 'review_type', 'review_id', 'authors',
#        'title', 'image_rev', 'score', 'deck_rev', 'good', 'bad', 'body',
#        'lede', 'game', 'releases', 'site_detail_url_rev', 'game_title',
#        'game_id_rev', 'release_date', 'description', 'game_id', 'name', 'deck',
#        'image', 'genres', 'themes', 'franchises', 'images_api_url',
#        'reviews_api_url', 'articles_api_url', 'videos_api_url',
#        'releases_api_url', 'site_detail_url'],
#       dtype='object')

# %%
game_reviews.drop(columns=['review_id', 'game_id_rev', 'game_id', 'publish_date',
    'site_detail_url', 'game_id_rev', 'videos_api_url', 'articles_api_url', 'reviews_api_url',
    'images_api_url', 'releases_api_url', 'image', 'image_rev', 'deck_rev',
    'site_detail_url_rev', 'deck', 'update_date', 'review_type',  
    'release_date', 'name', 'lede', 'title', 'good', 'bad', 'body',
    'game', 'franchises'
    ], inplace=True)

# %%
game_reviews.drop(columns=['description'], inplace=True)

game_reviews.columns
# Out:
# Index(['authors', 'score', 'releases', 'game_title', 'genres', 'themes'], dtype='object')

# %%
game_reviews.reset_index(drop=True, inplace=True)

# %%
game_reviews.head()
# Out:
#           authors score                                           releases  \
# 0  Jeff Sengstack   6.9  [{'upc': None, 'distribution_type': 'Retail', ...
# 1  Jeff Sengstack   6.9  [{'upc': None, 'distribution_type': 'Retail', ...
# 2  Jeff Sengstack   6.9  [{'upc': None, 'distribution_type': 'Retail', ...
# 3  Jeff Sengstack   6.9  [{'upc': None, 'distribution_type': 'Retail', ...
# 4  Jeff Sengstack   6.9  [{'upc': None, 'distribution_type': 'Retail', ...
#
#              game_title                                             genres  \
# 0  Under a Killing Moon  [{'name': '3D'}, {'name': 'Action'}, {'name': ...
# 1  Under a Killing Moon  [{'name': '3D'}, {'name': 'Action'}, {'name': ...
# 2  Under a Killing Moon  [{'name': '3D'}, {'name': 'Action'}, {'name': ...
# 3  Under a Killing Moon  [{'name': '3D'}, {'name': 'Action'}, {'name': ...
# 4  Under a Killing Moon  [{'name': '3D'}, {'name': 'Action'}, {'name': ...
#
#                  themes
# 0  [{'name': 'Modern'}]
# 1  [{'name': 'Modern'}]
# 2  [{'name': 'Modern'}]
# 3  [{'name': 'Modern'}]
# 4  [{'name': 'Modern'}]

# %%
game_reviews['releases'][0]
# Out:
# [{'upc': None,
#   'distribution_type': 'Retail',
#   'id': 8526,
#   'name': 'Under a Killing Moon',
#   'region': 'Europe',
#   'platform': 'PC',
#   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id:8526'},
#  {'upc': '081192712049',
#   'distribution_type': 'Retail',
#   'id': 8525,
#   'name': 'Under a Killing Moon',
#   'region': 'North America',
#   'platform': 'PC',
#   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id:8525'}]

# %%
def getPlatforms (x):

    platforms = []

    try:
        for i in range(len(x)):
            if x[i]['platform'] not in platforms:
                platforms.append(x[i]['platform'])
    except:
        return []
    return platforms

# %%
game_reviews['platforms'] = game_reviews['releases'].apply(lambda x: getPlatforms(x))

# %%
game_reviews_bak = game_reviews.copy()

# %%
def getGenres (x):

    genres = []

    try:
        for i in range(len(x)):
            if x[i]['name'] not in genres:
                genres.append(x[i]['name'])
    except:
        return []
    return genres

# %%
game_reviews['genres'] = game_reviews['genres'].apply(lambda x: getGenres(x))

# %%
game_reviews
# Out:
#               authors score  \
# 0      Jeff Sengstack   6.9
# 1      Jeff Sengstack   6.9
# 2      Jeff Sengstack   6.9
# 3      Jeff Sengstack   6.9
# 4      Jeff Sengstack   6.9
# ...               ...   ...
# 15736     Kevin Mical   8.4
# 15737     Kevin Mical   8.4
# 15738     Kevin Mical   8.4
# 15739     Kevin Mical   8.4
# 15740     Kevin Mical   8.4
#
#                                                 releases  \
# 0      [{'upc': None, 'distribution_type': 'Retail', ...
# 1      [{'upc': None, 'distribution_type': 'Retail', ...
# 2      [{'upc': None, 'distribution_type': 'Retail', ...
# 3      [{'upc': None, 'distribution_type': 'Retail', ...
# 4      [{'upc': None, 'distribution_type': 'Retail', ...
# ...                                                  ...
# 15736  [{'upc': None, 'distribution_type': 'Retail', ...
# 15737  [{'upc': None, 'distribution_type': 'Retail', ...
# 15738  [{'upc': None, 'distribution_type': 'Retail', ...
# 15739  [{'upc': None, 'distribution_type': 'Retail', ...
# 15740  [{'upc': None, 'distribution_type': 'Retail', ...
#
#                  game_title                               genres  \
# 0      Under a Killing Moon  [3D, Action, First-Person, Shooter]
# 1      Under a Killing Moon  [3D, Action, First-Person, Shooter]
# 2      Under a Killing Moon  [3D, Action, First-Person, Shooter]
# 3      Under a Killing Moon  [3D, Action, First-Person, Shooter]
# 4      Under a Killing Moon  [3D, Action, First-Person, Shooter]
# ...                     ...                                  ...
# 15736        Steel Panthers                 [Flight, Simulation]
# 15737        Steel Panthers                 [Flight, Simulation]
# 15738        Steel Panthers                 [Flight, Simulation]
# 15739        Steel Panthers                 [Flight, Simulation]
# 15740        Steel Panthers                 [Flight, Simulation]
#
#                      themes platforms
# 0      [{'name': 'Modern'}]      [PC]
# 1      [{'name': 'Modern'}]      [PC]
# 2      [{'name': 'Modern'}]      [PC]
# 3      [{'name': 'Modern'}]      [PC]
# 4      [{'name': 'Modern'}]      [PC]
# ...                     ...       ...
# 15736                    []      [PC]
# 15737                    []      [PC]
# 15738                    []      [PC]
# 15739                    []      [PC]
# 15740                    []      [PC]
#
# [15741 rows x 7 columns]

# %%
def getThemes (x):

    themes = []

    try:
        for i in range(len(x)):
            if x[i]['name'] not in themes:
                themes.append(x[i]['name'])
    except:
        return []
    return themes

# %%
game_reviews['themes'] = game_reviews['themes'].apply(lambda x: getThemes(x))

# %%
game_reviews.drop(columns=['releases'], inplace=True)

# %%
game_reviews
# Out:
#               authors score  \
# 0      Jeff Sengstack   6.9
# 1      Jeff Sengstack   6.9
# 2      Jeff Sengstack   6.9
# 3      Jeff Sengstack   6.9
# 4      Jeff Sengstack   6.9
# ...               ...   ...
# 15736     Kevin Mical   8.4
# 15737     Kevin Mical   8.4
# 15738     Kevin Mical   8.4
# 15739     Kevin Mical   8.4
# 15740     Kevin Mical   8.4
#
#                                                 releases  \
# 0      [{'upc': None, 'distribution_type': 'Retail', ...
# 1      [{'upc': None, 'distribution_type': 'Retail', ...
# 2      [{'upc': None, 'distribution_type': 'Retail', ...
# 3      [{'upc': None, 'distribution_type': 'Retail', ...
# 4      [{'upc': None, 'distribution_type': 'Retail', ...
# ...                                                  ...
# 15736  [{'upc': None, 'distribution_type': 'Retail', ...
# 15737  [{'upc': None, 'distribution_type': 'Retail', ...
# 15738  [{'upc': None, 'distribution_type': 'Retail', ...
# 15739  [{'upc': None, 'distribution_type': 'Retail', ...
# 15740  [{'upc': None, 'distribution_type': 'Retail', ...
#
#                  game_title                               genres    themes  \
# 0      Under a Killing Moon  [3D, Action, First-Person, Shooter]  [Modern]
# 1      Under a Killing Moon  [3D, Action, First-Person, Shooter]  [Modern]
# 2      Under a Killing Moon  [3D, Action, First-Person, Shooter]  [Modern]
# 3      Under a Killing Moon  [3D, Action, First-Person, Shooter]  [Modern]
# 4      Under a Killing Moon  [3D, Action, First-Person, Shooter]  [Modern]
# ...                     ...                                  ...       ...
# 15736        Steel Panthers                 [Flight, Simulation]        []
# 15737        Steel Panthers                 [Flight, Simulation]        []
# 15738        Steel Panthers                 [Flight, Simulation]        []
# 15739        Steel Panthers                 [Flight, Simulation]        []
# 15740        Steel Panthers                 [Flight, Simulation]        []
#
#       platforms
# 0          [PC]
# 1          [PC]
# 2          [PC]
# 3          [PC]
# 4          [PC]
# ...         ...
# 15736      [PC]
# 15737      [PC]
# 15738      [PC]
# 15739      [PC]
# 15740      [PC]
#
# [15741 rows x 7 columns]

# %%
game_reviews_bak1 = game_reviews.copy()

# %%
game_reviews['genres'].value_counts()
# Out:
# genres
# [3D, Action, First-Person, Shooter]    2226
# [Flight, Simulation]                   1908
# [Trivia/Board Game]                    1908
# [Adventure]                            1431
# [Real-Time, Strategy]                   954
# [Simulation]                            795
# [Strategy, Turn-Based]                  795
# [Strategy]                              636
# [Action, Role-Playing]                  636
# [2D, Action, Beat-'Em-Up]               477
# [2D, Action, Platformer]                477
# [Role-Playing]                          477
# [3D, Action, Platformer]                477
# [3D, Adventure, Third-Person]           318
# [Action, Adventure]                     318
# [Golf, Simulation, Sports]              318
# [Compilation]                           318
# [2D, Action, Fixed-Screen, Shooter]     318
# [Pinball]                               159
# [Driving/Racing, Simulation]            159
# [Action, Puzzle]                        159
# [3D, Action, Shooter, Third-Person]     159
# [Puzzle]                                159
# [Action]                                159
# Name: count, dtype: int64

# %%
game_reviews.to_csv("data/gamespot_reviews.csv", sep=',', encoding='utf-8', index=False)
