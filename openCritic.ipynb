# %%
import pandas as pd

openc_critic_df = pd.read_csv('data/control.csv')

openc_critic_df.head()
# Out:
#       Game                                 Game Page   Publication  \
# 0  Control  https://opencritic.com/game/7858/control    Giant Bomb
# 1  Control  https://opencritic.com/game/7858/control           EGM
# 2  Control  https://opencritic.com/game/7858/control      Stevivor
# 3  Control  https://opencritic.com/game/7858/control  Impulsegamer
# 4  Control  https://opencritic.com/game/7858/control   MonsterVine
#
#    Is Top Critic?  Normalized Score        Rating Recommendation  \
# 0            True             100.0   5 out of 5            True
# 1            True             100.0  10 out of 10           True
# 2            True             100.0  10 out of 10           True
# 3            True             100.0    5 out of 5           True
# 4           False             100.0    5 out of 5           True
#
#            Author Language                                         Review URL  \
# 0  Jeff Gerstmann  English  http://www.giantbomb.com/reviews/control-pc-re...
# ...

# %%
openc_critic_df['Game'].value_counts()
# Out:
# Control    182
# Name: Game, dtype: int64
