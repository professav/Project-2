# %%
import os
from dotenv import load_dotenv
import requests
import pandas as pd
import numpy as np

load_dotenv()

# Get the API key from the environment
API_KEY = os.getenv("STEAM_API_KEY")
MARKET_API_KEY = os.getenv("STEAM_MARKET_API_KEY")

# %%
steam_store = "https://store.steampowered.com"
# /appreviews/10500?
base_params = {
    "json": 1,
    "language": "english",
    "filter": "recent",
    "num_per_page": 100,
    "cursor": "*",
}

# %%
steam_market = 'https://api.steamapis.com'
app_list_url = f"{steam_market}/market/apps?"
market_params = {
    "api_key": MARKET_API_KEY
}

# %%
all_games = requests.get(app_list_url, params=market_params).json()

# %%
all_games_df = pd.DataFrame(all_games)

# %%
all_games_df.head()
# Out:
#     appID                                    name  is_free  \
# 0   10500  Total War: EMPIRE – Definitive Edition    False
# 1  391070                              Stellar 2D    False
# 2  576670                           Sky Is Arrows    False
# 3  256410        Might & Magic: Duel of Champions     True
# 4  546330    SPACE MOUSE 35th Anniversary edition    False
#
#                                       price_overview
# 0  {'final_formatted': '$24.99', 'initial_formatt...
# 1  {'final_formatted': '$0.99', 'initial_formatte...
# 2  {'final_formatted': '$9.99', 'initial_formatte...
# 3                                                NaN
# 4  {'final_formatted': '$4.99', 'initial_formatte...

# %%
all_games_df.to_csv("data/steam/all_games.csv", index=False)

# %%
all_games_df = pd.read_csv("data/steam/all_games.csv")

# %%
all_games_df.head()
# Out:
#     appID                                    name  is_free  \
# 0   10500  Total War: EMPIRE – Definitive Edition    False
# 1  391070                              Stellar 2D    False
# 2  576670                           Sky Is Arrows    False
# 3  256410        Might & Magic: Duel of Champions     True
# 4  546330    SPACE MOUSE 35th Anniversary edition    False
#
#                                       price_overview
# 0  {'final_formatted': '$24.99', 'initial_formatt...
# 1  {'final_formatted': '$0.99', 'initial_formatte...
# 2  {'final_formatted': '$9.99', 'initial_formatte...
# 3                                                NaN
# 4  {'final_formatted': '$4.99', 'initial_formatte...

# %%
game_reviews = pd.read_csv("data/steam/long_reviews.csv")

# %%
reviews_from_api = []

last_review = game_reviews.tail(1)["name"].values[0]

# offset = 0
offset = all_games_df[all_games_df['name'] == last_review].index[0]

# %%
remaining_games = all_games_df.iloc[offset:]

# %%
import urllib

for i, app_id in enumerate(remaining_games["appID"]):
    cursor = '*'
    reviews_url = f"{steam_store}/appreviews/{app_id}?"
    past_cursors = []

    positive = False

    print(f"Getting reviews for {app_id} ({i+1}/{len(remaining_games)})", end="\r")

    while cursor:
        params = base_params.copy()
        params["cursor"] = cursor
        params["review_type"] = 'positive' if positive else "negative"
        url = f"{reviews_url}"\
        + f"json=1&language=english&filter=recent&num_per_page=100&"\
        + f"cursor={cursor}&review_type={'positive' if positive else 'negative'}"
        # print(url)
        res = requests.get(url)
        try:
            reviews = res.json()
        except:
            try:
                with open(res, encoding='utf-8-sig') as r:
                    reviews = r.json()
            except:
                print('Unable to process response')
                break
        cursor = reviews.get("cursor")

        if cursor:
            cursor = urllib.parse.quote(cursor)
        if cursor in past_cursors:
            if positive:
                break
            positive = True
            cursor = '*'
            past_cursors = []
            continue
        if not cursor:
            if positive:
                break
            positive = True
            cursor = '*'
            past_cursors = []
            continue
        past_cursors.append(cursor)

        if cursor:
            for review in reviews["reviews"]:
                author = review["author"]["steamid"]

                reviews_from_api.append({
                    "app_id": app_id,
                    "author": author,
                    "recommended": positive
                })
        else:
            break

# sort reviews by review_weighted
reviews_df = pd.DataFrame(reviews_from_api)

# set max number of rows to none
pd.set_option('display.max_rows', None)

reviews_df.tail()
# Out:
# Getting reviews for 997070 (3566/3566))
#          app_id             author  recommended
# 6946148  997070  76561198053561661         True
# 6946149  997070  76561198030558053         True
# 6946150  997070  76561198068534122         True
# 6946151  997070  76561197983376650         True
# 6946152  997070  76561198230763904         True

# %%
reviews_df = pd.DataFrame(reviews_from_api)

# %%
name_id = pd.DataFrame(all_games_df[['appID', 'name']])
name_id = name_id.rename(columns={'appID': 'app_id'})

# %%
reviews_df = reviews_df.merge(name_id, on='app_id')
display(reviews_df.head(2))
display(reviews_df.tail(2))
# Out:
#    app_id             author  recommended                               name
# 0  976730  76561197978030555        False  Halo: The Master Chief Collection
# 1  976730  76561198001410886        False  Halo: The Master Chief Collection
#          app_id             author  recommended               name
# 6956117  997070  76561197983376650         True  Marvel's Avengers
# 6956118  997070  76561198230763904         True  Marvel's Avengers

# %%
reviews_df.drop(columns=['app_id'], inplace=True)

# %%
display(reviews_df.head(2))
display(reviews_df.tail(2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 display(reviews_df.head(2))
#       2 display(reviews_df.tail(2))
#
# NameError: name 'reviews_df' is not defined

# %%
display(game_reviews.head())
display(game_reviews.tail())
# Out:
#               author  recommended                                    name
# 0  76561198140439494        False  Total War: EMPIRE – Definitive Edition
# 1  76561198001149578        False  Total War: EMPIRE – Definitive Edition
# 2  76561199667392107        False  Total War: EMPIRE – Definitive Edition
# 3  76561198024411821        False  Total War: EMPIRE – Definitive Edition
# 4  76561198297284962        False  Total War: EMPIRE – Definitive Edition
#                      author  recommended               name
# 19596706  76561198053561661         True  Marvel's Avengers
# 19596707  76561198030558053         True  Marvel's Avengers
# 19596708  76561198068534122         True  Marvel's Avengers
# 19596709  76561197983376650         True  Marvel's Avengers
# 19596710  76561198230763904         True  Marvel's Avengers

# %%
# add the new reviews to the existing reviews

merged_reviews = pd.concat([game_reviews, reviews_df])

# %%
len(reviews)
# Out:
# 4

# %%
len(merged_reviews)
# Out:
# 19634690

# %%
merged_reviews.duplicated().sum()
# Out:
# 37979

# %%
merged_reviews.drop(columns=['app_id'], inplace=True)

# %%
game_reviews = merged_reviews.drop_duplicates()
game_reviews.to_csv("data/steam/long_reviews.csv", index=False)

# %%
display(len(reviews_df))
display(reviews_df.duplicated().sum())
reviews_df.drop_duplicates(inplace=True)
display(reviews_df.duplicated().sum())

display(len(reviews_df))
# Out:
# 1000
# 0
# 0
# 1000

# %%
print(reviews_df.head())
print(reviews_df.tail())
# Out:
#    app_id             author  recommended
# 0   10500  76561199100623571        False
# 1   10500  76561198140439494        False
# 2   10500  76561198001149578        False
# 3   10500  76561199667392107        False
# 4   10500  76561198024411821        False
#      app_id             author  recommended
# 995   10500  76561197991580763        False
# 996   10500  76561198120223099        False
# 997   10500  76561197970772540        False
# 998   10500  76561198170133919        False
# 999   10500  76561198152676419        False

# %%
game_reviews = pd.read_csv("data/steam/long_reviews.csv")

# %%
reviews = pd.read_csv("data/steam/long_reviews.csv")

last_review = reviews.tail(1)["name"].values[0]

# %%
last_review
# Out:
# "Marvel's Avengers"

# %%
# find drop any author that has less than 2 reviews
author_counts = game_reviews['author'].value_counts()
author_counts = author_counts[author_counts >= 5]

gr_no_dup = game_reviews[game_reviews['author'].isin(author_counts.index)]

len(gr_no_dup)
# Out:
# 7114866

# %%
gr_no_dup['recommended'] = gr_no_dup['recommended'].apply(lambda x: 1 if x else -1)

gr_no_dup.head()
# Out:
# C:\Users\Tim\AppData\Local\Temp\ipykernel_25328\2831849930.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gr_no_dup['recommended'] = gr_no_dup['recommended'].apply(lambda x: 1 if x else -1)
#                author  recommended                                    name
# 1   76561198001149578           -1  Total War: EMPIRE – Definitive Edition
# 4   76561198297284962           -1  Total War: EMPIRE – Definitive Edition
# 5   76561198039423947           -1  Total War: EMPIRE – Definitive Edition
# 11  76561198089482980           -1  Total War: EMPIRE – Definitive Edition
# 17  76561197997373898           -1  Total War: EMPIRE – Definitive Edition

# %%
gr_no_dup['recommended'].value_counts()
# Out:
#  1    5928675
# -1     962505
# Name: recommended, dtype: int64

# %% [markdown]
# Run the following 2 cells until the number ceases to change.

# %%
# delete games with less than 50 reviews
game_counts = gr_no_dup['name'].value_counts()
game_counts = game_counts[game_counts >= 50]

gr_no_dup = gr_no_dup[gr_no_dup['name'].isin(game_counts.index)]

# %%
author_counts = gr_no_dup['author'].value_counts()
author_counts = author_counts[author_counts >= 5]

gr_no_dup = gr_no_dup[gr_no_dup['author'].isin(author_counts.index)]

len(gr_no_dup)
# Out:
# 7008489

# %%
review_count = 0

MIN_GAME_REVIEWS = 100
MIN_AUTHOR_REVIEWS = 5

while len(gr_no_dup) != review_count:
    review_count = len(gr_no_dup)
    # drop games with less than 50 reviews
    game_counts = gr_no_dup['name'].value_counts()
    game_counts = game_counts[game_counts >= MIN_GAME_REVIEWS]

    gr_no_dup = gr_no_dup[gr_no_dup['name'].isin(game_counts.index)]

    # drop authors with less than 5 reviews
    author_counts = gr_no_dup['author'].value_counts()
    author_counts = author_counts[author_counts >= MIN_AUTHOR_REVIEWS]

    gr_no_dup = gr_no_dup[gr_no_dup['author'].isin(author_counts.index)]

# %%
store.close()

# %%
import threading

NUM_THREADS = 20

def pivot_reviews(df, results, i):
    print(f"Thread {i} started")
    pivot = df.pivot_table(index='name', columns='author', values='recommended').fillna(0)
    print(f"Thread {i} finished")
    results.append(pivot)
    return

def pivot_reviews_threaded(df):
    threads = []
    results = []
    chunk_size = len(df) // NUM_THREADS
    chunks = [df.iloc[i:i + chunk_size] for i in range(0, len(df), chunk_size)]

    for i, chunk in enumerate(chunks):
        t = threading.Thread(target=pivot_reviews, args=(chunk, results, i))
        threads.append(t)
        t.start()

    for t in threads:
        t.join()

    # get all the responses from the treads

    return pd.concat([r for r in results]).fillna(0)

# %%
game_pivot.to_csv("data/steam/game_pivot.csv")

# %%
game_pivot = pivot_reviews_threaded(gr_no_dup)
# Out:
# Thread 0 started
# Thread 1 started
# Thread 2 started
# Thread 3 started
# Thread 4 started
# Thread 5 started
# Thread 6 started
# Thread 7 started
# Thread 8 started
# Thread 9 started
# Thread 10 started
# Thread 11 started
# Thread 12 started
# Thread 13 started
# Thread 14 started
# Thread 15 started
# Thread 16 started
# Thread 17 started
# Thread 18 started
# Thread 19 started
# Thread 0 finished
# Thread 6 finished
# Thread 3 finished
# Thread 2 finished
# Thread 1 finished
# Thread 9 finished
# Thread 4 finished
# Thread 11 finished
# Thread 5 finished
# Thread 14 finished
# Thread 7 finished
# Thread 18 finished
# Thread 17 finished
# Thread 10 finished
# Thread 13 finished
# Thread 16 finished
# Thread 19 finished
# Thread 12 finished
# Thread 8 finished
# Thread 15 finished

# %%
# game_pivot.fillna(0, inplace=True)

# display(game_pivot.describe())
display(game_pivot.shape)

# rotate the pivot table
rot_pivot = game_pivot.T
display(rot_pivot.shape)

# write the pivot table to an xl file
rot_pivot.to_excel("data/steam/rot_pivot.xlsx")
# Out:
# (3541, 744562)
# (744562, 3541)

# %%
game_pivot.fillna(0, inplace=True)
display(game_pivot.head(3))
display(game_pivot.tail(3))
# Out:
# author             76561197960267984  76561197960268765  76561197960269230  \
# name
# 100% Orange Juice                0.0                0.0                0.0
# Arma Tactics                     0.0                0.0                0.0
# BIT.TRIP RUNNER                  0.0                0.0                0.0
#
# author             76561197960269409  76561197960269579  76561197960269906  \
# name
# 100% Orange Juice                0.0                0.0                0.0
# Arma Tactics                     0.0                0.0                0.0
# BIT.TRIP RUNNER                  0.0                0.0                0.0
#
# author             76561197960270054  76561197960270526  76561197960270999  \
# name
# 100% Orange Juice                0.0                0.0                0.0
# Arma Tactics                     0.0                0.0                0.0
# BIT.TRIP RUNNER                  0.0                0.0                0.0
#
# author             76561197960271098  ...  76561198070882733  \
# name                                  ...
# 100% Orange Juice                0.0  ...                0.0
# Arma Tactics                     0.0  ...                0.0
# BIT.TRIP RUNNER                  0.0  ...                0.0
#
# author             76561198105301758  76561198106538641  76561198134309424  \
# name
# 100% Orange Juice                0.0                0.0                0.0
# Arma Tactics                     0.0                0.0                0.0
# BIT.TRIP RUNNER                  0.0                0.0                0.0
#
# author             76561198145028927  76561198150849751  76561198156238166  \
# name
# 100% Orange Juice                0.0                0.0                0.0
# Arma Tactics                     0.0                0.0                0.0
# BIT.TRIP RUNNER                  0.0                0.0                0.0
#
# author             76561198797517897  76561199384271546  76561198023504801
# name
# 100% Orange Juice                0.0                0.0                0.0
# Arma Tactics                     0.0                0.0                0.0
# BIT.TRIP RUNNER                  0.0                0.0                0.0
#
# [3 rows x 744562 columns]
# author                                   76561197960267984  76561197960268765  \
# name
# klocki                                                 0.0                0.0
# planetarian HD                                         0.0                0.0
# 永遠消失的幻想鄉 ～ The Disappearing of Gensokyo                0.0                0.0
#
# author                                   76561197960269230  76561197960269409  \
# name
# klocki                                                 0.0                0.0
# planetarian HD                                         0.0                0.0
# 永遠消失的幻想鄉 ～ The Disappearing of Gensokyo                0.0                0.0
#
# author                                   76561197960269579  76561197960269906  \
# name
# klocki                                                 0.0                0.0
# planetarian HD                                         0.0                0.0
# 永遠消失的幻想鄉 ～ The Disappearing of Gensokyo                0.0                0.0
#
# author                                   76561197960270054  76561197960270526  \
# name
# klocki                                                 0.0                0.0
# planetarian HD                                         0.0                0.0
# 永遠消失的幻想鄉 ～ The Disappearing of Gensokyo                0.0                0.0
#
# author                                   76561197960270999  76561197960271098  \
# name
# klocki                                                 0.0                0.0
# planetarian HD                                         0.0                0.0
# 永遠消失的幻想鄉 ～ The Disappearing of Gensokyo                0.0                0.0
#
# author                                   ...  76561198070882733  \
# name                                     ...
# klocki                                   ...                0.0
# planetarian HD                           ...                0.0
# 永遠消失的幻想鄉 ～ The Disappearing of Gensokyo  ...                0.0
#
# author                                   76561198105301758  76561198106538641  \
# name
# klocki                                                 0.0                0.0
# planetarian HD                                         0.0                0.0
# 永遠消失的幻想鄉 ～ The Disappearing of Gensokyo                0.0                0.0
#
# author                                   76561198134309424  76561198145028927  \
# name
# klocki                                                 0.0                0.0
# planetarian HD                                         0.0                0.0
# 永遠消失的幻想鄉 ～ The Disappearing of Gensokyo                0.0                0.0
#
# author                                   76561198150849751  76561198156238166  \
# name
# klocki                                                 0.0                0.0
# planetarian HD                                         0.0                0.0
# 永遠消失的幻想鄉 ～ The Disappearing of Gensokyo                0.0                0.0
#
# author                                   76561198797517897  76561199384271546  \
# name
# klocki                                                 0.0                0.0
# planetarian HD                                         0.0                0.0
# 永遠消失的幻想鄉 ～ The Disappearing of Gensokyo                0.0                0.0
#
# author                                   76561198023504801
# name
# klocki                                                 0.0
# planetarian HD                                         0.0
# 永遠消失的幻想鄉 ～ The Disappearing of Gensokyo                0.0
#
# [3 rows x 744562 columns]

# %%
# create a sparse matrix using game_pivot
from scipy.sparse import csr_matrix
game_sparse = csr_matrix(game_pivot)

# %%
from sklearn.neighbors import NearestNeighbors

knn = NearestNeighbors( algorithm='brute', n_neighbors=10)
knn.fit(game_sparse)
# Out:
# NearestNeighbors(algorithm='brute', n_neighbors=10)

# %%
import pickle

with open("data/steam/knn.pkl", "wb") as f:
    pickle.dump(knn, f)

# %%
import pyarrow as pa
import pyarrow.parquet as pq

pq.write_table(pa.Table.from_pandas(game_pivot), 'data/steam/game_pivot.parquet')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       1 import pyarrow as pa
#       2 import pyarrow.parquet as pq
# ----> 4 pq.write_table(pa.Table.from_pandas(game_pivot), 'data/steam/game_pivot.parquet', thrift_compression='zstd')
#
# File c:\Users\Tim\anaconda3\envs\dev\lib\site-packages\pyarrow\parquet\core.py:3104, in write_table(table, where, row_group_size, version, use_dictionary, compression, write_statistics, use_deprecated_int96_timestamps, coerce_timestamps, allow_truncated_timestamps, data_page_size, flavor, filesystem, compression_level, use_byte_stream_split, column_encoding, data_page_version, use_compliant_nested_type, encryption_properties, write_batch_size, dictionary_pagesize_limit, store_schema, write_page_index, **kwargs)
#    3102 use_int96 = use_deprecated_int96_timestamps
#    3103 try:
# -> 3104     with ParquetWriter(
#    3105             where, table.schema,
#    3106             filesystem=filesystem,
#    3107             version=version,
#    3108             flavor=flavor,
#    3109             use_dictionary=use_dictionary,
#    3110             write_statistics=write_statistics,
#    3111             coerce_timestamps=coerce_timestamps,
#    3112             data_page_size=data_page_size,
#    3113             allow_truncated_timestamps=allow_truncated_timestamps,
#    3114             compression=compression,
#    3115             use_deprecated_int96_timestamps=use_int96,
#    3116             compression_level=compression_level,
#    3117             use_byte_stream_split=use_byte_stream_split,
#    3118             column_encoding=column_encoding,
#    3119             data_page_version=data_page_version,
#    3120             use_compliant_nested_type=use_compliant_nested_type,
#    3121             encryption_properties=encryption_properties,
#    3122             write_batch_size=write_batch_size,
#    3123             dictionary_pagesize_limit=dictionary_pagesize_limit,
#    3124             store_schema=store_schema,
#    3125             write_page_index=write_page_index,
#    3126             **kwargs) as writer:
#    3127         writer.write_table(table, row_group_size=row_group_size)
#    3128 except Exception:
#
# File c:\Users\Tim\anaconda3\envs\dev\lib\site-packages\pyarrow\parquet\core.py:1016, in ParquetWriter.__init__(self, where, schema, filesystem, flavor, version, use_dictionary, compression, write_statistics, use_deprecated_int96_timestamps, compression_level, use_byte_stream_split, column_encoding, writer_engine_version, data_page_version, use_compliant_nested_type, encryption_properties, write_batch_size, dictionary_pagesize_limit, store_schema, write_page_index, **options)
#    1014 self._metadata_collector = options.pop('metadata_collector', None)
#    1015 engine_version = 'V2'
# -> 1016 self.writer = _parquet.ParquetWriter(
#    1017     sink, schema,
#    1018     version=version,
#    1019     compression=compression,
#    1020     use_dictionary=use_dictionary,
#    1021     write_statistics=write_statistics,
#    1022     use_deprecated_int96_timestamps=use_deprecated_int96_timestamps,
#    1023     compression_level=compression_level,
#    1024     use_byte_stream_split=use_byte_stream_split,
#    1025     column_encoding=column_encoding,
#    1026     writer_engine_version=engine_version,
#    1027     data_page_version=data_page_version,
#    1028     use_compliant_nested_type=use_compliant_nested_type,
#    1029     encryption_properties=encryption_properties,
#    1030     write_batch_size=write_batch_size,
#    1031     dictionary_pagesize_limit=dictionary_pagesize_limit,
#    1032     store_schema=store_schema,
#    1033     write_page_index=write_page_index,
#    1034     **options)
#    1035 self.is_open = True
#
# File c:\Users\Tim\anaconda3\envs\dev\lib\site-packages\pyarrow\_parquet.pyx:1807, in pyarrow._parquet.ParquetWriter.__cinit__()
#
# TypeError: __cinit__() got an unexpected keyword argument 'thrift_compression'
